# %%
# For tips on running notebooks in Google Colab, see
# https://pytorch.org/tutorials/beginner/colab
# %matplotlib inline

# %% [markdown]
# Train a Mario-playing RL Agent
# ==============================
#
# **Authors:** [Yuansong Feng](https://github.com/YuansongFeng), [Suraj
# Subramanian](https://github.com/suraj813), [Howard
# Wang](https://github.com/hw26), [Steven
# Guo](https://github.com/GuoYuzhang).
#
# This tutorial walks you through the fundamentals of Deep Reinforcement
# Learning. At the end, you will implement an AI-powered Mario (using
# [Double Deep Q-Networks](https://arxiv.org/pdf/1509.06461.pdf)) that can
# play the game by itself.
#
# Although no prior knowledge of RL is necessary for this tutorial, you
# can familiarize yourself with these RL
# [concepts](https://spinningup.openai.com/en/latest/spinningup/rl_intro.html),
# and have this handy
# [cheatsheet](https://colab.research.google.com/drive/1eN33dPVtdPViiS1njTW_-r-IYCDTFU7N)
# as your companion. The full code is available
# [here](https://github.com/yuansongFeng/MadMario/).
#
# ![](https://pytorch.org/tutorials/_static/img/mario.gif)

# %% [markdown]
# ``` {.bash}
# %%bash
# pip install gym-super-mario-bros==7.4.0
# pip install tensordict==0.3.0
# pip install torchrl==0.3.0
# ```

# %%
import torch
from torch import nn
from torchvision import transforms as T
from PIL import Image
import numpy as np
from pathlib import Path
from collections import deque
import random, datetime, os

# Gym is an OpenAI toolkit for RL
import gym
from gym.spaces import Box
from gym.wrappers import FrameStack

# NES Emulator for OpenAI Gym
from nes_py.wrappers import JoypadSpace

# Super Mario environment for OpenAI Gym
import gym_super_mario_bros

from tensordict import TensorDict
from torchrl.data import TensorDictReplayBuffer, LazyMemmapStorage
from torchrl.data.replay_buffers import TensorDictReplayBuffer, ListStorage

# %% [markdown]
# RL Definitions
# ==============
#
# **Environment** The world that an agent interacts with and learns from.
#
# **Action** $a$ : How the Agent responds to the Environment. The set of
# all possible Actions is called *action-space*.
#
# **State** $s$ : The current characteristic of the Environment. The set
# of all possible States the Environment can be in is called
# *state-space*.
#
# **Reward** $r$ : Reward is the key feedback from Environment to Agent.
# It is what drives the Agent to learn and to change its future action. An
# aggregation of rewards over multiple time steps is called **Return**.
#
# **Optimal Action-Value function** $Q^*(s,a)$ : Gives the expected return
# if you start in state $s$, take an arbitrary action $a$, and then for
# each future time step take the action that maximizes returns. $Q$ can be
# said to stand for the "quality" of the action in a state. We try to
# approximate this function.

# %% [markdown]
# Environment
# ===========
#
# Initialize Environment
# ----------------------
#
# In Mario, the environment consists of tubes, mushrooms and other
# components.
#
# When Mario makes an action, the environment responds with the changed
# (next) state, reward and other info.

# %%
# Initialize Super Mario environment (in v0.26 change render mode to 'human' to see results on the screen)
if gym.__version__ < '0.26':
    env = gym_super_mario_bros.make("SuperMarioBros-1-1-v0", new_step_api=True)
else:
    env = gym_super_mario_bros.make("SuperMarioBros-1-1-v0", render_mode='human', apply_api_compatibility=True)

# Limit the action-space to
#   0. walk right
#   1. jump right
env = JoypadSpace(env, [["right"], ["right", "A"]])

env.reset()
next_state, reward, done, trunc, info = env.step(action=0)
print(f"{next_state.shape},\n {reward},\n {done},\n {info}")
# Out:
# c:\Users\joser\OneDrive\Documents\robotics_programming\mario_env_py311\Lib\site-packages\gym\envs\registration.py:555: UserWarning: WARN: The environment SuperMarioBros-1-1-v0 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# c:\Users\joser\OneDrive\Documents\robotics_programming\mario_env_py311\Lib\site-packages\gym\envs\registration.py:627: UserWarning: WARN: The environment creator metadata doesn't include `render_modes`, contains: ['render.modes', 'video.frames_per_second']
#   logger.warn(
# (240, 256, 3),
#  0.0,
#  False,
#  {'coins': 0, 'flag_get': False, 'life': 2, 'score': 0, 'stage': 1, 'status': 'small', 'time': 400, 'world': 1, 'x_pos': 40, 'y_pos': 79}

# %% [markdown]
# Preprocess Environment
# ======================
#
# Environment data is returned to the agent in `next_state`. As you saw
# above, each state is represented by a `[3, 240, 256]` size array. Often
# that is more information than our agent needs; for instance, Mario's
# actions do not depend on the color of the pipes or the sky!
#
# We use **Wrappers** to preprocess environment data before sending it to
# the agent.
#
# `GrayScaleObservation` is a common wrapper to transform an RGB image to
# grayscale; doing so reduces the size of the state representation without
# losing useful information. Now the size of each state: `[1, 240, 256]`
#
# `ResizeObservation` downsamples each observation into a square image.
# New size: `[1, 84, 84]`
#
# `SkipFrame` is a custom wrapper that inherits from `gym.Wrapper` and
# implements the `step()` function. Because consecutive frames don't vary
# much, we can skip n-intermediate frames without losing much information.
# The n-th frame aggregates rewards accumulated over each skipped frame.
#
# `FrameStack` is a wrapper that allows us to squash consecutive frames of
# the environment into a single observation point to feed to our learning
# model. This way, we can identify if Mario was landing or jumping based
# on the direction of his movement in the previous several frames.

# %%
class SkipFrame(gym.Wrapper):
    def __init__(self, env, skip):
        """Return only every `skip`-th frame"""
        super().__init__(env)
        self._skip = skip

    def step(self, action):
        """Repeat action, and sum reward"""
        total_reward = 0.0
        for i in range(self._skip):
            # Accumulate reward and repeat the same action
            obs, reward, done, trunk, info = self.env.step(action)
            total_reward += reward
            if done:
                break
        return obs, total_reward, done, trunk, info


class GrayScaleObservation(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        obs_shape = self.observation_space.shape[:2]
        self.observation_space = Box(low=0, high=255, shape=obs_shape, dtype=np.uint8)

    def permute_orientation(self, observation):
        # permute [H, W, C] array to [C, H, W] tensor
        observation = np.transpose(observation, (2, 0, 1))
        observation = torch.tensor(observation.copy(), dtype=torch.float)
        return observation

    def observation(self, observation):
        observation = self.permute_orientation(observation)
        transform = T.Grayscale()
        observation = transform(observation)
        return observation


class ResizeObservation(gym.ObservationWrapper):
    def __init__(self, env, shape):
        super().__init__(env)
        if isinstance(shape, int):
            self.shape = (shape, shape)
        else:
            self.shape = tuple(shape)

        obs_shape = self.shape + self.observation_space.shape[2:]
        self.observation_space = Box(low=0, high=255, shape=obs_shape, dtype=np.uint8)

    def observation(self, observation):
        transforms = T.Compose(
            [T.Resize(self.shape, antialias=True), T.Normalize(0, 255)]
        )
        observation = transforms(observation).squeeze(0)
        return observation


# Apply Wrappers to environment
env = SkipFrame(env, skip=4)
env = GrayScaleObservation(env)
env = ResizeObservation(env, shape=84)
if gym.__version__ < '0.26':
    env = FrameStack(env, num_stack=4, new_step_api=True)
else:
    env = FrameStack(env, num_stack=4)

# %% [markdown]
# After applying the above wrappers to the environment, the final wrapped
# state consists of 4 gray-scaled consecutive frames stacked together, as
# shown above in the image on the left. Each time Mario makes an action,
# the environment responds with a state of this structure. The structure
# is represented by a 3-D array of size `[4, 84, 84]`.
#
# ![](https://pytorch.org/tutorials/_static/img/mario_env.png)

# %% [markdown]
# Agent
# =====
#
# We create a class `Mario` to represent our agent in the game. Mario
# should be able to:
#
# -   **Act** according to the optimal action policy based on the current
#     state (of the environment).
# -   **Remember** experiences. Experience = (current state, current
#     action, reward, next state). Mario *caches* and later *recalls* his
#     experiences to update his action policy.
# -   **Learn** a better action policy over time

# %%
class Mario:
    def __init__():
        pass

    def act(self, state):
        """Given a state, choose an epsilon-greedy action"""
        pass

    def cache(self, experience):
        """Add the experience to memory"""
        pass

    def recall(self):
        """Sample experiences from memory"""
        pass

    def learn(self):
        """Update online action value (Q) function with a batch of experiences"""
        pass

# %% [markdown]
# In the following sections, we will populate Mario's parameters and
# define his functions.

# %% [markdown]
# Act
# ===
#
# For any given state, an agent can choose to do the most optimal action
# (**exploit**) or a random action (**explore**).
#
# Mario randomly explores with a chance of `self.exploration_rate`; when
# he chooses to exploit, he relies on `MarioNet` (implemented in `Learn`
# section) to provide the most optimal action.

# %%
class Mario:
    def __init__(self, state_dim, action_dim, save_dir):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.save_dir = save_dir

        self.device = "cuda" if torch.cuda.is_available() else "cpu"

        # Mario's DNN to predict the most optimal action - we implement this in the Learn section
        self.net = MarioNet(self.state_dim, self.action_dim).float()
        self.net = self.net.to(device=self.device)

        self.exploration_rate = 1.0
        self.exploration_rate_decay = 0.9999997126  # unused in linear, kept for compatibility
        self.exploration_rate_min = 0.1
        self.curr_step = 0

        self.save_every = 5e5  # no. of experiences between saving Mario Net

    def act(self, state):
        """
        Given a state, choose an epsilon-greedy action and update value of step.
        """
        if np.random.rand() < self.exploration_rate:
            action_idx = np.random.randint(self.action_dim)
        else:
            state = state[0].__array__() if isinstance(state, tuple) else state.__array__()
            state = torch.tensor(state, device=self.device).unsqueeze(0)
            action_values = self.net(state, model="online")
            action_idx = torch.argmax(action_values, axis=1).item()

        self.curr_step += 1
        return action_idx

# %% [markdown]
# Cache and Recall
# ================
#
# These two functions serve as Mario's "memory" process.
#
# `cache()`: Each time Mario performs an action, he stores the
# `experience` to his memory. His experience includes the current *state*,
# *action* performed, *reward* from the action, the *next state*, and
# whether the game is *done*.
#
# `recall()`: Mario randomly samples a batch of experiences from his
# memory, and uses that to learn the game.

# %%
class Mario(Mario):  # subclassing for continuity
    def __init__(self, state_dim, action_dim, save_dir):
        super().__init__(state_dim, action_dim, save_dir)
        # self.memory = TensorDictReplayBuffer(storage=LazyMemmapStorage(100000, device=torch.device("cpu")))

        self.memory = TensorDictReplayBuffer(storage=ListStorage(10_000))  # or more, depending on RAM
        
        self.batch_size = 32

    def cache(self, state, next_state, action, reward, done):
        """
        Store the experience to self.memory (replay buffer)

        Inputs:
        state (``LazyFrame``),
        next_state (``LazyFrame``),
        action (``int``),
        reward (``float``),
        done(``bool``))
        """
        def first_if_tuple(x):
            return x[0] if isinstance(x, tuple) else x
        state = first_if_tuple(state).__array__()
        next_state = first_if_tuple(next_state).__array__()

        state = torch.tensor(state)
        next_state = torch.tensor(next_state)
        action = torch.tensor([action])
        reward = torch.tensor([reward])
        done = torch.tensor([done])

        # self.memory.append((state, next_state, action, reward, done,))
        self.memory.add(TensorDict({"state": state, "next_state": next_state, "action": action, "reward": reward, "done": done}, batch_size=[]))

    def recall(self):
        """
        Retrieve a batch of experiences from memory
        """
        batch = self.memory.sample(self.batch_size).to(self.device)
        state, next_state, action, reward, done = (batch.get(key) for key in ("state", "next_state", "action", "reward", "done"))
        return state, next_state, action.squeeze(), reward.squeeze(), done.squeeze()

# %% [markdown]
# Learn
# =====
#
# Mario uses the [DDQN algorithm](https://arxiv.org/pdf/1509.06461) under
# the hood. DDQN uses two ConvNets - $Q_{online}$ and $Q_{target}$ - that
# independently approximate the optimal action-value function.
#
# In our implementation, we share feature generator `features` across
# $Q_{online}$ and $Q_{target}$, but maintain separate FC classifiers for
# each. $\theta_{target}$ (the parameters of $Q_{target}$) is frozen to
# prevent updating by backprop. Instead, it is periodically synced with
# $\theta_{online}$ (more on this later).
#
# Neural Network
# --------------

# %%
class MarioNet(nn.Module):
    """mini CNN structure
  input -> (conv2d + relu) x 3 -> flatten -> (dense + relu) x 2 -> output
  """

    def __init__(self, input_dim, output_dim):
        super().__init__()
        c, h, w = input_dim

        if h != 84:
            raise ValueError(f"Expecting input height: 84, got: {h}")
        if w != 84:
            raise ValueError(f"Expecting input width: 84, got: {w}")

        self.online = self.__build_cnn(c, output_dim)

        self.target = self.__build_cnn(c, output_dim)
        self.target.load_state_dict(self.online.state_dict())

        # Q_target parameters are frozen.
        for p in self.target.parameters():
            p.requires_grad = False

    def forward(self, input, model):
        if model == "online":
            return self.online(input)
        elif model == "target":
            return self.target(input)

    def __build_cnn(self, c, output_dim):
        return nn.Sequential(
            nn.Conv2d(in_channels=c, out_channels=32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(3136, 512),
            nn.ReLU(),
            nn.Linear(512, output_dim),
        )

# %% [markdown]
# TD Estimate & TD Target
# =======================
#
# Two values are involved in learning:
#
# **TD Estimate** - the predicted optimal $Q^*$ for a given state $s$
#
# $${TD}_e = Q_{online}^*(s,a)$$
#
# **TD Target** - aggregation of current reward and the estimated $Q^*$ in
# the next state $s'$
#
# $$a' = argmax_{a} Q_{online}(s', a)$$
#
# $${TD}_t = r + \gamma Q_{target}^*(s',a')$$
#
# Because we don't know what next action $a'$ will be, we use the action
# $a'$ maximizes $Q_{online}$ in the next state $s'$.
#
# Notice we use the
# [\@torch.no\_grad()](https://pytorch.org/docs/stable/generated/torch.no_grad.html#no-grad)
# decorator on `td_target()` to disable gradient calculations here
# (because we don't need to backpropagate on $\theta_{target}$).

# %%
class Mario(Mario):
    def __init__(self, state_dim, action_dim, save_dir):
        super().__init__(state_dim, action_dim, save_dir)
        self.gamma = 0.9

    def td_estimate(self, state, action):
        current_Q = self.net(state, model="online")[
            np.arange(0, self.batch_size), action
        ]  # Q_online(s,a)
        return current_Q

    @torch.no_grad()
    def td_target(self, reward, next_state, done):
        next_state_Q = self.net(next_state, model="online")
        best_action = torch.argmax(next_state_Q, axis=1)
        next_Q = self.net(next_state, model="target")[
            np.arange(0, self.batch_size), best_action
        ]
        return (reward + (1 - done.float()) * self.gamma * next_Q).float()

# %% [markdown]
# Updating the model
# ==================
#
# As Mario samples inputs from his replay buffer, we compute $TD_t$ and
# $TD_e$ and backpropagate this loss down $Q_{online}$ to update its
# parameters $\theta_{online}$ ($\alpha$ is the learning rate `lr` passed
# to the `optimizer`)
#
# $$\theta_{online} \leftarrow \theta_{online} + \alpha \nabla(TD_e - TD_t)$$
#
# $\theta_{target}$ does not update through backpropagation. Instead, we
# periodically copy $\theta_{online}$ to $\theta_{target}$
#
# $$\theta_{target} \leftarrow \theta_{online}$$

# %%
class Mario(Mario):
    def __init__(self, state_dim, action_dim, save_dir):
        super().__init__(state_dim, action_dim, save_dir)
        self.optimizer = torch.optim.Adam(self.net.parameters(), lr=0.00025)
        self.loss_fn = torch.nn.SmoothL1Loss()

    def update_Q_online(self, td_estimate, td_target):
        loss = self.loss_fn(td_estimate, td_target)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        return loss.item()

    def sync_Q_target(self):
        self.net.target.load_state_dict(self.net.online.state_dict())

# %% [markdown]
# Save checkpoint
# ===============

# %%
class Mario(Mario):
    def save(self):
        save_path = (
            self.save_dir / f"mario_net_{int(self.curr_step // self.save_every)}.chkpt"
        )
        torch.save(
            dict(model=self.net.state_dict(), exploration_rate=self.exploration_rate),
            save_path,
        )
        print(f"MarioNet saved to {save_path} at step {self.curr_step}")

# %% [markdown]
# Putting it all together
# =======================

# %%
class Mario(Mario):
    def __init__(self, state_dim, action_dim, save_dir):
        super().__init__(state_dim, action_dim, save_dir)
        self.burnin = 1e4  # min. experiences before training
        self.learn_every = 3  # no. of experiences between updates to Q_online
        self.sync_every = 1e4  # no. of experiences between Q_target & Q_online sync

    def learn(self):
        if self.curr_step % self.sync_every == 0:
            self.sync_Q_target()

        if self.curr_step % self.save_every == 0:
            self.save()

        if self.curr_step < self.burnin:
            return None, None

        if self.curr_step % self.learn_every != 0:
            return None, None

        # Sample from memory
        state, next_state, action, reward, done = self.recall()

        # Get TD Estimate
        td_est = self.td_estimate(state, action)

        # Get TD Target
        td_tgt = self.td_target(reward, next_state, done)

        # Backpropagate loss through Q_online
        loss = self.update_Q_online(td_est, td_tgt)

        return (td_est.mean().item(), loss)

# %% [markdown]
# Logging
# =======

# %%
import numpy as np
import time, datetime
import matplotlib.pyplot as plt


class MetricLogger:
    def __init__(self, save_dir):
        self.save_log = save_dir / "log"
        with open(self.save_log, "w") as f:
            f.write(
                f"{'Episode':>8}{'Step':>8}{'Epsilon':>10}{'MeanReward':>15}"
                f"{'MeanLength':>15}{'MeanLoss':>15}{'MeanQValue':>15}"
                f"{'TimeDelta':>15}{'Time':>20}\n"
            )
        self.ep_rewards_plot = save_dir / "reward_plot.jpg"
        self.ep_lengths_plot = save_dir / "length_plot.jpg"
        self.ep_avg_losses_plot = save_dir / "loss_plot.jpg"
        self.ep_avg_qs_plot = save_dir / "q_plot.jpg"

        # History metrics
        self.ep_rewards = []
        self.ep_lengths = []
        self.ep_avg_losses = []
        self.ep_avg_qs = []

        # Moving averages, added for every call to record()
        self.moving_avg_ep_rewards = []
        self.moving_avg_ep_lengths = []
        self.moving_avg_ep_avg_losses = []
        self.moving_avg_ep_avg_qs = []

        # Current episode metric
        self.init_episode()

        # Timing
        self.record_time = time.time()

    def log_step(self, reward, loss, q):
        self.curr_ep_reward += reward
        self.curr_ep_length += 1
        if loss:
            self.curr_ep_loss += loss
            self.curr_ep_q += q
            self.curr_ep_loss_length += 1

    def log_episode(self):
        "Mark end of episode"
        self.ep_rewards.append(self.curr_ep_reward)
        self.ep_lengths.append(self.curr_ep_length)
        if self.curr_ep_loss_length == 0:
            ep_avg_loss = 0
            ep_avg_q = 0
        else:
            ep_avg_loss = np.round(self.curr_ep_loss / self.curr_ep_loss_length, 5)
            ep_avg_q = np.round(self.curr_ep_q / self.curr_ep_loss_length, 5)
        self.ep_avg_losses.append(ep_avg_loss)
        self.ep_avg_qs.append(ep_avg_q)

        self.init_episode()

    def init_episode(self):
        self.curr_ep_reward = 0.0
        self.curr_ep_length = 0
        self.curr_ep_loss = 0.0
        self.curr_ep_q = 0.0
        self.curr_ep_loss_length = 0

    def record(self, episode, epsilon, step):
        mean_ep_reward = np.round(np.mean(self.ep_rewards[-100:]), 3)
        mean_ep_length = np.round(np.mean(self.ep_lengths[-100:]), 3)
        mean_ep_loss = np.round(np.mean(self.ep_avg_losses[-100:]), 3)
        mean_ep_q = np.round(np.mean(self.ep_avg_qs[-100:]), 3)
        self.moving_avg_ep_rewards.append(mean_ep_reward)
        self.moving_avg_ep_lengths.append(mean_ep_length)
        self.moving_avg_ep_avg_losses.append(mean_ep_loss)
        self.moving_avg_ep_avg_qs.append(mean_ep_q)

        last_record_time = self.record_time
        self.record_time = time.time()
        time_since_last_record = np.round(self.record_time - last_record_time, 3)

        print(
            f"Episode {episode} - "
            f"Step {step} - "
            f"Epsilon {epsilon} - "
            f"Mean Reward {mean_ep_reward} - "
            f"Mean Length {mean_ep_length} - "
            f"Mean Loss {mean_ep_loss} - "
            f"Mean Q Value {mean_ep_q} - "
            f"Time Delta {time_since_last_record} - "
            f"Time {datetime.datetime.now().strftime('%Y-%m-%dT%H:%M:%S')}"
        )

        with open(self.save_log, "a") as f:
            f.write(
                f"{episode:8d}{step:8d}{epsilon:10.3f}"
                f"{mean_ep_reward:15.3f}{mean_ep_length:15.3f}{mean_ep_loss:15.3f}{mean_ep_q:15.3f}"
                f"{time_since_last_record:15.3f}"
                f"{datetime.datetime.now().strftime('%Y-%m-%dT%H:%M:%S'):>20}\n"
            )

        for metric in ["ep_lengths", "ep_avg_losses", "ep_avg_qs", "ep_rewards"]:
            plt.clf()
            plt.plot(getattr(self, f"moving_avg_{metric}"), label=f"moving_avg_{metric}")
            plt.legend()
            plt.savefig(getattr(self, f"{metric}_plot"))

# %% [markdown]
# Let's play!
# ===========
#
# In this example we run the training loop for 40 episodes, but for Mario
# to truly learn the ways of his world, we suggest running the loop for at
# least 40,000 episodes!

# %%
use_cuda = torch.cuda.is_available()
print(f"Using CUDA: {use_cuda}")
print()

save_dir = Path("checkpoints_non_mobile_10000eps") / datetime.datetime.now().strftime("%Y-%m-%dT%H-%M-%S")
save_dir.mkdir(parents=True)

mario = Mario(state_dim=(4, 84, 84), action_dim=env.action_space.n, save_dir=save_dir)

logger = MetricLogger(save_dir)

episodes = 10000
for e in range(episodes):
    # Apply linear epsilon decay per episode
    mario.exploration_rate = max(
        mario.exploration_rate_min,
        1.0 - (1.0 - mario.exploration_rate_min) * (e / episodes)
    )

    state = env.reset()

    # Play the game!
    while True:
        # Run agent on the state
        action = mario.act(state)

        # Agent performs action
        next_state, reward, done, trunc, info = env.step(action)

        # Remember
        mario.cache(state, next_state, action, reward, done)

        # Learn
        q, loss = mario.learn()

        # Logging
        logger.log_step(reward, loss, q)

        # Update state
        state = next_state

        # Check if end of game
        if done or info["flag_get"]:
            break

    logger.log_episode()

    # if (e % 20 == 0) or (e == episodes - 1):
    logger.record(episode=e, epsilon=mario.exploration_rate, step=mario.curr_step)

env.close()
# Out:
# Using CUDA: True
#
# Episode 0 - Step 146 - Epsilon 1.0 - Mean Reward 717.0 - Mean Length 146.0 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 2.862 - Time 2025-05-11T16:07:59
# Episode 1 - Step 425 - Epsilon 0.99991 - Mean Reward 752.5 - Mean Length 212.5 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 5.332 - Time 2025-05-11T16:08:04
# Episode 2 - Step 465 - Epsilon 0.99982 - Mean Reward 578.667 - Mean Length 155.0 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 0.969 - Time 2025-05-11T16:08:05
# Episode 3 - Step 850 - Epsilon 0.99973 - Mean Reward 685.5 - Mean Length 212.5 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 13.774 - Time 2025-05-11T16:08:19
# Episode 4 - Step 951 - Epsilon 0.99964 - Mean Reward 672.4 - Mean Length 190.2 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 4.685 - Time 2025-05-11T16:08:24
# Episode 5 - Step 1113 - Epsilon 0.99955 - Mean Reward 666.167 - Mean Length 185.5 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 2.845 - Time 2025-05-11T16:08:27
# Episode 6 - Step 1584 - Epsilon 0.99946 - Mean Reward 710.429 - Mean Length 226.286 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 8.292 - Time 2025-05-11T16:08:35
# Episode 7 - Step 1690 - Epsilon 0.99937 - Mean Reward 698.875 - Mean Length 211.25 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 2.249 - Time 2025-05-11T16:08:37
# Episode 8 - Step 2205 - Epsilon 0.99928 - Mean Reward 728.667 - Mean Length 245.0 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 9.278 - Time 2025-05-11T16:08:47
# Episode 9 - Step 2245 - Epsilon 0.99919 - Mean Reward 678.9 - Mean Length 224.5 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 0.842 - Time 2025-05-11T16:08:47
# Episode 10 - Step 2609 - Epsilon 0.9991 - Mean Reward 684.545 - Mean Length 237.182 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 6.049 - Time 2025-05-11T16:08:53
# Episode 11 - Step 2962 - Epsilon 0.99901 - Mean Reward 735.833 - Mean Length 246.833 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 6.494 - Time 2025-05-11T16:09:00
# Episode 12 - Step 3167 - Epsilon 0.99892 - Mean Reward 740.923 - Mean Length 243.615 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 3.847 - Time 2025-05-11T16:09:04
# Episode 13 - Step 3490 - Epsilon 0.99883 - Mean Reward 736.714 - Mean Length 249.286 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 6.166 - Time 2025-05-11T16:09:10
# Episode 14 - Step 3599 - Epsilon 0.99874 - Mean Reward 728.467 - Mean Length 239.933 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 2.183 - Time 2025-05-11T16:09:12
# Episode 15 - Step 4030 - Epsilon 0.99865 - Mean Reward 744.438 - Mean Length 251.875 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 7.783 - Time 2025-05-11T16:09:20
# Episode 16 - Step 4187 - Epsilon 0.99856 - Mean Reward 738.059 - Mean Length 246.294 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 3.067 - Time 2025-05-11T16:09:23
# Episode 17 - Step 4589 - Epsilon 0.99847 - Mean Reward 752.667 - Mean Length 254.944 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 7.361 - Time 2025-05-11T16:09:30
# Episode 18 - Step 4989 - Epsilon 0.99838 - Mean Reward 780.737 - Mean Length 262.579 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 7.399 - Time 2025-05-11T16:09:38
# Episode 19 - Step 5147 - Epsilon 0.99829 - Mean Reward 778.45 - Mean Length 257.35 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 3.038 - Time 2025-05-11T16:09:41
# Episode 20 - Step 5815 - Epsilon 0.9982 - Mean Reward 786.095 - Mean Length 276.905 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 11.846 - Time 2025-05-11T16:09:53
# Episode 21 - Step 5855 - Epsilon 0.99811 - Mean Reward 760.864 - Mean Length 266.136 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 0.956 - Time 2025-05-11T16:09:54
# Episode 22 - Step 6011 - Epsilon 0.99802 - Mean Reward 755.435 - Mean Length 261.348 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 2.992 - Time 2025-05-11T16:09:57
# Episode 23 - Step 6147 - Epsilon 0.99793 - Mean Reward 754.792 - Mean Length 256.125 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 2.605 - Time 2025-05-11T16:09:59
# Episode 24 - Step 6811 - Epsilon 0.99784 - Mean Reward 751.76 - Mean Length 272.44 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 11.905 - Time 2025-05-11T16:10:11
# Episode 25 - Step 7489 - Epsilon 0.99775 - Mean Reward 759.038 - Mean Length 288.038 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 12.317 - Time 2025-05-11T16:10:23
# Episode 26 - Step 7781 - Epsilon 0.99766 - Mean Reward 757.963 - Mean Length 288.185 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 5.38 - Time 2025-05-11T16:10:29
# Episode 27 - Step 8311 - Epsilon 0.99757 - Mean Reward 765.5 - Mean Length 296.821 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 9.51 - Time 2025-05-11T16:10:38
# Episode 28 - Step 8351 - Epsilon 0.99748 - Mean Reward 747.069 - Mean Length 287.966 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 0.957 - Time 2025-05-11T16:10:39
# Episode 29 - Step 8391 - Epsilon 0.99739 - Mean Reward 729.867 - Mean Length 279.7 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 0.952 - Time 2025-05-11T16:10:40
# Episode 30 - Step 8552 - Epsilon 0.9973 - Mean Reward 726.806 - Mean Length 275.871 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 3.059 - Time 2025-05-11T16:10:43
# Episode 31 - Step 8592 - Epsilon 0.99721 - Mean Reward 711.312 - Mean Length 268.5 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 0.961 - Time 2025-05-11T16:10:44
# Episode 32 - Step 8755 - Epsilon 0.99712 - Mean Reward 709.0 - Mean Length 265.303 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 3.11 - Time 2025-05-11T16:10:47
# Episode 33 - Step 9455 - Epsilon 0.99703 - Mean Reward 723.971 - Mean Length 278.088 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 12.521 - Time 2025-05-11T16:11:00
# Episode 34 - Step 9621 - Epsilon 0.99694 - Mean Reward 720.457 - Mean Length 274.886 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 3.188 - Time 2025-05-11T16:11:03
# Episode 35 - Step 9903 - Epsilon 0.99685 - Mean Reward 721.028 - Mean Length 275.083 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 5.202 - Time 2025-05-11T16:11:08
# Episode 36 - Step 10004 - Epsilon 0.99676 - Mean Reward 718.297 - Mean Length 270.378 - Mean Loss 0.05 - Mean Q Value 0.001 - Time Delta 2.329 - Time 2025-05-11T16:11:11
# Episode 37 - Step 10107 - Epsilon 0.99667 - Mean Reward 715.842 - Mean Length 265.974 - Mean Loss 0.115 - Mean Q Value 0.021 - Time Delta 2.508 - Time 2025-05-11T16:11:13
# Episode 38 - Step 10151 - Epsilon 0.99658 - Mean Reward 703.205 - Mean Length 260.282 - Mean Loss 0.175 - Mean Q Value 0.037 - Time Delta 1.38 - Time 2025-05-11T16:11:14
# Episode 39 - Step 10429 - Epsilon 0.99649 - Mean Reward 711.05 - Mean Length 260.725 - Mean Loss 0.236 - Mean Q Value 0.058 - Time Delta 6.293 - Time 2025-05-11T16:11:21
# Episode 40 - Step 10837 - Epsilon 0.9964 - Mean Reward 718.195 - Mean Length 264.317 - Mean Loss 0.271 - Mean Q Value 0.104 - Time Delta 8.892 - Time 2025-05-11T16:11:30
# Episode 41 - Step 10877 - Epsilon 0.99631 - Mean Reward 706.595 - Mean Length 258.976 - Mean Loss 0.285 - Mean Q Value 0.163 - Time Delta 1.129 - Time 2025-05-11T16:11:31
# Episode 42 - Step 11265 - Epsilon 0.99622 - Mean Reward 713.512 - Mean Length 261.977 - Mean Loss 0.294 - Mean Q Value 0.218 - Time Delta 8.492 - Time 2025-05-11T16:11:39
# Episode 43 - Step 11363 - Epsilon 0.99613 - Mean Reward 711.523 - Mean Length 258.25 - Mean Loss 0.301 - Mean Q Value 0.271 - Time Delta 2.329 - Time 2025-05-11T16:11:42
# Episode 44 - Step 11521 - Epsilon 0.99604 - Mean Reward 709.2 - Mean Length 256.022 - Mean Loss 0.306 - Mean Q Value 0.323 - Time Delta 3.591 - Time 2025-05-11T16:11:45
# Episode 45 - Step 11561 - Epsilon 0.99595 - Mean Reward 698.804 - Mean Length 251.326 - Mean Loss 0.311 - Mean Q Value 0.379 - Time Delta 1.094 - Time 2025-05-11T16:11:46
# Episode 46 - Step 11717 - Epsilon 0.99586 - Mean Reward 697.468 - Mean Length 249.298 - Mean Loss 0.315 - Mean Q Value 0.43 - Time Delta 3.589 - Time 2025-05-11T16:11:50
# Episode 47 - Step 12123 - Epsilon 0.99577 - Mean Reward 696.646 - Mean Length 252.562 - Mean Loss 0.318 - Mean Q Value 0.479 - Time Delta 8.876 - Time 2025-05-11T16:11:59
# Episode 48 - Step 12968 - Epsilon 0.99568 - Mean Reward 701.061 - Mean Length 264.653 - Mean Loss 0.321 - Mean Q Value 0.526 - Time Delta 18.236 - Time 2025-05-11T16:12:17
# Episode 49 - Step 13327 - Epsilon 0.99559 - Mean Reward 707.08 - Mean Length 266.54 - Mean Loss 0.322 - Mean Q Value 0.567 - Time Delta 7.865 - Time 2025-05-11T16:12:25
# Episode 50 - Step 13370 - Epsilon 0.9955 - Mean Reward 697.647 - Mean Length 262.157 - Mean Loss 0.322 - Mean Q Value 0.599 - Time Delta 1.169 - Time 2025-05-11T16:12:26
# Episode 51 - Step 14305 - Epsilon 0.99541 - Mean Reward 706.808 - Mean Length 275.096 - Mean Loss 0.323 - Mean Q Value 0.636 - Time Delta 20.133 - Time 2025-05-11T16:12:46
# Episode 52 - Step 14407 - Epsilon 0.99532 - Mean Reward 705.132 - Mean Length 271.83 - Mean Loss 0.325 - Mean Q Value 0.673 - Time Delta 2.418 - Time 2025-05-11T16:12:49
# Episode 53 - Step 14447 - Epsilon 0.99523 - Mean Reward 696.352 - Mean Length 267.537 - Mean Loss 0.327 - Mean Q Value 0.704 - Time Delta 1.353 - Time 2025-05-11T16:12:50
# Episode 54 - Step 14558 - Epsilon 0.99514 - Mean Reward 694.945 - Mean Length 264.691 - Mean Loss 0.328 - Mean Q Value 0.737 - Time Delta 2.655 - Time 2025-05-11T16:12:53
# Episode 55 - Step 14665 - Epsilon 0.99505 - Mean Reward 693.75 - Mean Length 261.875 - Mean Loss 0.33 - Mean Q Value 0.767 - Time Delta 2.495 - Time 2025-05-11T16:12:55
# Episode 56 - Step 14783 - Epsilon 0.99496 - Mean Reward 692.333 - Mean Length 259.351 - Mean Loss 0.331 - Mean Q Value 0.798 - Time Delta 2.736 - Time 2025-05-11T16:12:58
# Episode 57 - Step 14954 - Epsilon 0.99487 - Mean Reward 693.672 - Mean Length 257.828 - Mean Loss 0.332 - Mean Q Value 0.832 - Time Delta 3.889 - Time 2025-05-11T16:13:02
# Episode 58 - Step 14994 - Epsilon 0.99478 - Mean Reward 685.831 - Mean Length 254.136 - Mean Loss 0.332 - Mean Q Value 0.864 - Time Delta 1.126 - Time 2025-05-11T16:13:03
# Episode 59 - Step 15729 - Epsilon 0.99469 - Mean Reward 694.833 - Mean Length 262.15 - Mean Loss 0.333 - Mean Q Value 0.892 - Time Delta 16.16 - Time 2025-05-11T16:13:19
# Episode 60 - Step 15851 - Epsilon 0.9946 - Mean Reward 692.984 - Mean Length 259.852 - Mean Loss 0.333 - Mean Q Value 0.918 - Time Delta 2.84 - Time 2025-05-11T16:13:22
# Episode 61 - Step 16070 - Epsilon 0.99451 - Mean Reward 694.71 - Mean Length 259.194 - Mean Loss 0.334 - Mean Q Value 0.947 - Time Delta 4.903 - Time 2025-05-11T16:13:27
# Episode 62 - Step 16372 - Epsilon 0.99442 - Mean Reward 695.873 - Mean Length 259.873 - Mean Loss 0.335 - Mean Q Value 0.974 - Time Delta 6.662 - Time 2025-05-11T16:13:33
# Episode 63 - Step 16412 - Epsilon 0.99433 - Mean Reward 688.609 - Mean Length 256.438 - Mean Loss 0.336 - Mean Q Value 1.004 - Time Delta 1.128 - Time 2025-05-11T16:13:34
# Episode 64 - Step 16513 - Epsilon 0.99424 - Mean Reward 687.554 - Mean Length 254.046 - Mean Loss 0.338 - Mean Q Value 1.027 - Time Delta 2.398 - Time 2025-05-11T16:13:37
# Episode 65 - Step 16557 - Epsilon 0.99415 - Mean Reward 680.5 - Mean Length 250.864 - Mean Loss 0.338 - Mean Q Value 1.053 - Time Delta 1.202 - Time 2025-05-11T16:13:38
# Episode 66 - Step 17325 - Epsilon 0.99406 - Mean Reward 684.119 - Mean Length 258.582 - Mean Loss 0.339 - Mean Q Value 1.078 - Time Delta 16.939 - Time 2025-05-11T16:13:55
# Episode 67 - Step 17495 - Epsilon 0.99397 - Mean Reward 682.985 - Mean Length 257.279 - Mean Loss 0.34 - Mean Q Value 1.104 - Time Delta 3.837 - Time 2025-05-11T16:13:59
# Episode 68 - Step 17703 - Epsilon 0.99388 - Mean Reward 688.116 - Mean Length 256.565 - Mean Loss 0.341 - Mean Q Value 1.128 - Time Delta 4.715 - Time 2025-05-11T16:14:04
# Episode 69 - Step 17743 - Epsilon 0.99379 - Mean Reward 681.586 - Mean Length 253.471 - Mean Loss 0.342 - Mean Q Value 1.154 - Time Delta 1.122 - Time 2025-05-11T16:14:05
# Episode 70 - Step 17783 - Epsilon 0.9937 - Mean Reward 675.239 - Mean Length 250.465 - Mean Loss 0.343 - Mean Q Value 1.176 - Time Delta 1.136 - Time 2025-05-11T16:14:06
# Episode 71 - Step 17953 - Epsilon 0.99361 - Mean Reward 674.667 - Mean Length 249.347 - Mean Loss 0.344 - Mean Q Value 1.199 - Time Delta 4.082 - Time 2025-05-11T16:14:10
# Episode 72 - Step 17993 - Epsilon 0.99352 - Mean Reward 668.589 - Mean Length 246.479 - Mean Loss 0.343 - Mean Q Value 1.225 - Time Delta 1.106 - Time 2025-05-11T16:14:11
# Episode 73 - Step 18512 - Epsilon 0.99343 - Mean Reward 668.243 - Mean Length 250.162 - Mean Loss 0.344 - Mean Q Value 1.248 - Time Delta 11.663 - Time 2025-05-11T16:14:23
# Episode 74 - Step 18620 - Epsilon 0.99334 - Mean Reward 667.707 - Mean Length 248.267 - Mean Loss 0.344 - Mean Q Value 1.27 - Time Delta 2.559 - Time 2025-05-11T16:14:25
# Episode 75 - Step 19015 - Epsilon 0.99325 - Mean Reward 668.987 - Mean Length 250.197 - Mean Loss 0.345 - Mean Q Value 1.291 - Time Delta 8.967 - Time 2025-05-11T16:14:34
# Episode 76 - Step 19131 - Epsilon 0.99316 - Mean Reward 667.961 - Mean Length 248.455 - Mean Loss 0.346 - Mean Q Value 1.309 - Time Delta 2.709 - Time 2025-05-11T16:14:37
# Episode 77 - Step 19177 - Epsilon 0.99307 - Mean Reward 662.179 - Mean Length 245.859 - Mean Loss 0.348 - Mean Q Value 1.326 - Time Delta 1.246 - Time 2025-05-11T16:14:38
# Episode 78 - Step 19284 - Epsilon 0.99298 - Mean Reward 661.747 - Mean Length 244.101 - Mean Loss 0.349 - Mean Q Value 1.346 - Time Delta 2.556 - Time 2025-05-11T16:14:41
# Episode 79 - Step 19324 - Epsilon 0.99289 - Mean Reward 656.362 - Mean Length 241.55 - Mean Loss 0.351 - Mean Q Value 1.366 - Time Delta 1.147 - Time 2025-05-11T16:14:42
# Episode 80 - Step 19632 - Epsilon 0.9928 - Mean Reward 660.741 - Mean Length 242.37 - Mean Loss 0.351 - Mean Q Value 1.385 - Time Delta 6.85 - Time 2025-05-11T16:14:49
# Episode 81 - Step 19858 - Epsilon 0.99271 - Mean Reward 665.195 - Mean Length 242.171 - Mean Loss 0.353 - Mean Q Value 1.405 - Time Delta 5.171 - Time 2025-05-11T16:14:54
# Episode 82 - Step 20323 - Epsilon 0.99262 - Mean Reward 666.217 - Mean Length 244.855 - Mean Loss 0.357 - Mean Q Value 1.443 - Time Delta 10.594 - Time 2025-05-11T16:15:04
# Episode 83 - Step 20426 - Epsilon 0.99253 - Mean Reward 665.595 - Mean Length 243.167 - Mean Loss 0.359 - Mean Q Value 1.489 - Time Delta 2.643 - Time 2025-05-11T16:15:07
# Episode 84 - Step 20785 - Epsilon 0.99244 - Mean Reward 669.506 - Mean Length 244.529 - Mean Loss 0.361 - Mean Q Value 1.538 - Time Delta 8.171 - Time 2025-05-11T16:15:15
# Episode 85 - Step 21349 - Epsilon 0.99235 - Mean Reward 672.988 - Mean Length 248.244 - Mean Loss 0.363 - Mean Q Value 1.581 - Time Delta 12.47 - Time 2025-05-11T16:15:28
# Episode 86 - Step 21389 - Epsilon 0.99226 - Mean Reward 667.908 - Mean Length 245.851 - Mean Loss 0.364 - Mean Q Value 1.623 - Time Delta 1.355 - Time 2025-05-11T16:15:29
# Episode 87 - Step 21429 - Epsilon 0.99217 - Mean Reward 662.943 - Mean Length 243.511 - Mean Loss 0.367 - Mean Q Value 1.664 - Time Delta 1.162 - Time 2025-05-11T16:15:30
# Episode 88 - Step 21977 - Epsilon 0.99208 - Mean Reward 662.674 - Mean Length 246.933 - Mean Loss 0.368 - Mean Q Value 1.702 - Time Delta 12.153 - Time 2025-05-11T16:15:42
# Episode 89 - Step 22649 - Epsilon 0.99199 - Mean Reward 668.856 - Mean Length 251.656 - Mean Loss 0.369 - Mean Q Value 1.74 - Time Delta 15.017 - Time 2025-05-11T16:15:57
# Episode 90 - Step 22750 - Epsilon 0.9919 - Mean Reward 668.319 - Mean Length 250.0 - Mean Loss 0.37 - Mean Q Value 1.779 - Time Delta 2.437 - Time 2025-05-11T16:16:00
# Episode 91 - Step 22854 - Epsilon 0.99181 - Mean Reward 667.87 - Mean Length 248.413 - Mean Loss 0.371 - Mean Q Value 1.816 - Time Delta 2.524 - Time 2025-05-11T16:16:02
# Episode 92 - Step 23007 - Epsilon 0.99172 - Mean Reward 667.108 - Mean Length 247.387 - Mean Loss 0.372 - Mean Q Value 1.856 - Time Delta 3.572 - Time 2025-05-11T16:16:06
# Episode 93 - Step 23652 - Epsilon 0.99163 - Mean Reward 671.447 - Mean Length 251.617 - Mean Loss 0.373 - Mean Q Value 1.893 - Time Delta 14.183 - Time 2025-05-11T16:16:20
# Episode 94 - Step 23692 - Epsilon 0.99154 - Mean Reward 666.811 - Mean Length 249.389 - Mean Loss 0.373 - Mean Q Value 1.923 - Time Delta 1.119 - Time 2025-05-11T16:16:21
# Episode 95 - Step 24218 - Epsilon 0.99145 - Mean Reward 670.031 - Mean Length 252.271 - Mean Loss 0.374 - Mean Q Value 1.96 - Time Delta 11.673 - Time 2025-05-11T16:16:33
# Episode 96 - Step 24322 - Epsilon 0.99136 - Mean Reward 669.608 - Mean Length 250.742 - Mean Loss 0.374 - Mean Q Value 2.001 - Time Delta 2.512 - Time 2025-05-11T16:16:35
# Episode 97 - Step 24661 - Epsilon 0.99127 - Mean Reward 675.898 - Mean Length 251.643 - Mean Loss 0.375 - Mean Q Value 2.037 - Time Delta 7.667 - Time 2025-05-11T16:16:43
# Episode 98 - Step 24828 - Epsilon 0.99118 - Mean Reward 675.475 - Mean Length 250.788 - Mean Loss 0.376 - Mean Q Value 2.071 - Time Delta 3.837 - Time 2025-05-11T16:16:47
# Episode 99 - Step 25191 - Epsilon 0.99109 - Mean Reward 676.43 - Mean Length 251.91 - Mean Loss 0.376 - Mean Q Value 2.101 - Time Delta 8.206 - Time 2025-05-11T16:16:55
# Episode 100 - Step 25413 - Epsilon 0.991 - Mean Reward 679.64 - Mean Length 252.67 - Mean Loss 0.38 - Mean Q Value 2.154 - Time Delta 5.155 - Time 2025-05-11T16:17:00
# Episode 101 - Step 25570 - Epsilon 0.99091 - Mean Reward 678.12 - Mean Length 251.45 - Mean Loss 0.385 - Mean Q Value 2.207 - Time Delta 3.953 - Time 2025-05-11T16:17:04
# Episode 102 - Step 25674 - Epsilon 0.99082 - Mean Reward 682.08 - Mean Length 252.09 - Mean Loss 0.389 - Mean Q Value 2.263 - Time Delta 2.511 - Time 2025-05-11T16:17:07
# Episode 103 - Step 25854 - Epsilon 0.99073 - Mean Reward 679.21 - Mean Length 250.04 - Mean Loss 0.394 - Mean Q Value 2.319 - Time Delta 4.371 - Time 2025-05-11T16:17:11
# Episode 104 - Step 25894 - Epsilon 0.99064 - Mean Reward 675.32 - Mean Length 249.43 - Mean Loss 0.398 - Mean Q Value 2.378 - Time Delta 1.133 - Time 2025-05-11T16:17:12
# Episode 105 - Step 25937 - Epsilon 0.99055 - Mean Reward 671.23 - Mean Length 248.24 - Mean Loss 0.402 - Mean Q Value 2.431 - Time Delta 1.17 - Time 2025-05-11T16:17:13
# Episode 106 - Step 26325 - Epsilon 0.99046 - Mean Reward 669.13 - Mean Length 247.41 - Mean Loss 0.406 - Mean Q Value 2.486 - Time Delta 8.824 - Time 2025-05-11T16:17:22
# Episode 107 - Step 26539 - Epsilon 0.99037 - Mean Reward 673.35 - Mean Length 248.49 - Mean Loss 0.41 - Mean Q Value 2.541 - Time Delta 4.878 - Time 2025-05-11T16:17:27
# Episode 108 - Step 27266 - Epsilon 0.99028 - Mean Reward 686.38 - Mean Length 250.61 - Mean Loss 0.414 - Mean Q Value 2.596 - Time Delta 16.051 - Time 2025-05-11T16:17:43
# Episode 109 - Step 27381 - Epsilon 0.99019 - Mean Reward 689.91 - Mean Length 251.36 - Mean Loss 0.418 - Mean Q Value 2.655 - Time Delta 2.713 - Time 2025-05-11T16:17:46
# Episode 110 - Step 27421 - Epsilon 0.9901 - Mean Reward 684.81 - Mean Length 248.12 - Mean Loss 0.424 - Mean Q Value 2.704 - Time Delta 1.109 - Time 2025-05-11T16:17:47
# Episode 111 - Step 27786 - Epsilon 0.99001 - Mean Reward 684.68 - Mean Length 248.24 - Mean Loss 0.428 - Mean Q Value 2.763 - Time Delta 8.281 - Time 2025-05-11T16:17:55
# Episode 112 - Step 27905 - Epsilon 0.98992 - Mean Reward 682.66 - Mean Length 247.38 - Mean Loss 0.432 - Mean Q Value 2.82 - Time Delta 2.883 - Time 2025-05-11T16:17:58
# Episode 113 - Step 28006 - Epsilon 0.98983 - Mean Reward 682.04 - Mean Length 245.16 - Mean Loss 0.436 - Mean Q Value 2.88 - Time Delta 2.459 - Time 2025-05-11T16:18:01
# Episode 114 - Step 28224 - Epsilon 0.98974 - Mean Reward 683.61 - Mean Length 246.25 - Mean Loss 0.441 - Mean Q Value 2.941 - Time Delta 5.052 - Time 2025-05-11T16:18:06
# Episode 115 - Step 28264 - Epsilon 0.98965 - Mean Reward 676.08 - Mean Length 242.34 - Mean Loss 0.445 - Mean Q Value 2.999 - Time Delta 1.14 - Time 2025-05-11T16:18:07
# Episode 116 - Step 28362 - Epsilon 0.98956 - Mean Reward 675.98 - Mean Length 241.75 - Mean Loss 0.449 - Mean Q Value 3.057 - Time Delta 2.445 - Time 2025-05-11T16:18:09
# Episode 117 - Step 28523 - Epsilon 0.98947 - Mean Reward 672.32 - Mean Length 239.34 - Mean Loss 0.454 - Mean Q Value 3.119 - Time Delta 3.889 - Time 2025-05-11T16:18:13
# Episode 118 - Step 28928 - Epsilon 0.98938 - Mean Reward 667.09 - Mean Length 239.39 - Mean Loss 0.458 - Mean Q Value 3.179 - Time Delta 9.209 - Time 2025-05-11T16:18:22
# Episode 119 - Step 29037 - Epsilon 0.98929 - Mean Reward 666.0 - Mean Length 238.9 - Mean Loss 0.462 - Mean Q Value 3.24 - Time Delta 2.857 - Time 2025-05-11T16:18:25
# Episode 120 - Step 29077 - Epsilon 0.9892 - Mean Reward 658.92 - Mean Length 232.62 - Mean Loss 0.466 - Mean Q Value 3.301 - Time Delta 1.122 - Time 2025-05-11T16:18:26
# Episode 121 - Step 29374 - Epsilon 0.98911 - Mean Reward 666.73 - Mean Length 235.19 - Mean Loss 0.469 - Mean Q Value 3.36 - Time Delta 6.718 - Time 2025-05-11T16:18:33
# Episode 122 - Step 29414 - Epsilon 0.98902 - Mean Reward 662.68 - Mean Length 234.03 - Mean Loss 0.473 - Mean Q Value 3.416 - Time Delta 1.118 - Time 2025-05-11T16:18:34
# Episode 123 - Step 29532 - Epsilon 0.98893 - Mean Reward 661.2 - Mean Length 233.85 - Mean Loss 0.478 - Mean Q Value 3.476 - Time Delta 2.831 - Time 2025-05-11T16:18:37
# Episode 124 - Step 29638 - Epsilon 0.98884 - Mean Reward 660.67 - Mean Length 228.27 - Mean Loss 0.481 - Mean Q Value 3.537 - Time Delta 2.557 - Time 2025-05-11T16:18:40
# Episode 125 - Step 29855 - Epsilon 0.98875 - Mean Reward 658.31 - Mean Length 223.66 - Mean Loss 0.485 - Mean Q Value 3.6 - Time Delta 4.974 - Time 2025-05-11T16:18:45
# Episode 126 - Step 29895 - Epsilon 0.98866 - Mean Reward 653.32 - Mean Length 221.14 - Mean Loss 0.488 - Mean Q Value 3.66 - Time Delta 1.152 - Time 2025-05-11T16:18:46
# Episode 127 - Step 29993 - Epsilon 0.98857 - Mean Reward 649.89 - Mean Length 216.82 - Mean Loss 0.491 - Mean Q Value 3.72 - Time Delta 2.379 - Time 2025-05-11T16:18:48
# Episode 128 - Step 30033 - Epsilon 0.98848 - Mean Reward 649.89 - Mean Length 216.82 - Mean Loss 0.503 - Mean Q Value 3.798 - Time Delta 1.142 - Time 2025-05-11T16:18:49
# Episode 129 - Step 30073 - Epsilon 0.98839 - Mean Reward 649.89 - Mean Length 216.82 - Mean Loss 0.514 - Mean Q Value 3.89 - Time Delta 1.128 - Time 2025-05-11T16:18:50
# Episode 130 - Step 30113 - Epsilon 0.9883 - Mean Reward 645.85 - Mean Length 215.61 - Mean Loss 0.523 - Mean Q Value 3.984 - Time Delta 1.129 - Time 2025-05-11T16:18:52
# Episode 131 - Step 30633 - Epsilon 0.98821 - Mean Reward 656.07 - Mean Length 220.41 - Mean Loss 0.529 - Mean Q Value 4.076 - Time Delta 11.57 - Time 2025-05-11T16:19:03
# Episode 132 - Step 30751 - Epsilon 0.98812 - Mean Reward 655.62 - Mean Length 219.96 - Mean Loss 0.535 - Mean Q Value 4.162 - Time Delta 2.76 - Time 2025-05-11T16:19:06
# Episode 133 - Step 30914 - Epsilon 0.98803 - Mean Reward 649.79 - Mean Length 214.59 - Mean Loss 0.542 - Mean Q Value 4.252 - Time Delta 3.715 - Time 2025-05-11T16:19:10
# Episode 134 - Step 31205 - Epsilon 0.98794 - Mean Reward 656.73 - Mean Length 215.84 - Mean Loss 0.548 - Mean Q Value 4.344 - Time Delta 6.496 - Time 2025-05-11T16:19:16
# Episode 135 - Step 31306 - Epsilon 0.98785 - Mean Reward 655.52 - Mean Length 214.03 - Mean Loss 0.553 - Mean Q Value 4.445 - Time Delta 2.438 - Time 2025-05-11T16:19:19
# Episode 136 - Step 31852 - Epsilon 0.98776 - Mean Reward 672.38 - Mean Length 218.48 - Mean Loss 0.541 - Mean Q Value 4.541 - Time Delta 12.326 - Time 2025-05-11T16:19:31
# Episode 137 - Step 32109 - Epsilon 0.98767 - Mean Reward 676.44 - Mean Length 220.02 - Mean Loss 0.522 - Mean Q Value 4.634 - Time Delta 5.822 - Time 2025-05-11T16:19:37
# Episode 138 - Step 32271 - Epsilon 0.98758 - Mean Reward 680.56 - Mean Length 221.2 - Mean Loss 0.503 - Mean Q Value 4.726 - Time Delta 3.7 - Time 2025-05-11T16:19:40
# Episode 139 - Step 32311 - Epsilon 0.98749 - Mean Reward 672.7 - Mean Length 218.82 - Mean Loss 0.483 - Mean Q Value 4.818 - Time Delta 1.101 - Time 2025-05-11T16:19:41
# Episode 140 - Step 32651 - Epsilon 0.9874 - Mean Reward 669.38 - Mean Length 218.14 - Mean Loss 0.473 - Mean Q Value 4.906 - Time Delta 7.712 - Time 2025-05-11T16:19:49
# Episode 141 - Step 32841 - Epsilon 0.98731 - Mean Reward 677.5 - Mean Length 219.64 - Mean Loss 0.471 - Mean Q Value 4.984 - Time Delta 4.351 - Time 2025-05-11T16:19:54
# Episode 142 - Step 32881 - Epsilon 0.98722 - Mean Reward 669.77 - Mean Length 216.16 - Mean Loss 0.472 - Mean Q Value 5.07 - Time Delta 1.121 - Time 2025-05-11T16:19:55
# Episode 143 - Step 33669 - Epsilon 0.98713 - Mean Reward 675.47 - Mean Length 223.06 - Mean Loss 0.473 - Mean Q Value 5.145 - Time Delta 17.277 - Time 2025-05-11T16:20:12
# Episode 144 - Step 33942 - Epsilon 0.98704 - Mean Reward 676.32 - Mean Length 224.21 - Mean Loss 0.473 - Mean Q Value 5.218 - Time Delta 6.159 - Time 2025-05-11T16:20:18
# Episode 145 - Step 34050 - Epsilon 0.98695 - Mean Reward 680.02 - Mean Length 224.89 - Mean Loss 0.474 - Mean Q Value 5.289 - Time Delta 2.579 - Time 2025-05-11T16:20:21
# Episode 146 - Step 34646 - Epsilon 0.98686 - Mean Reward 683.28 - Mean Length 229.29 - Mean Loss 0.475 - Mean Q Value 5.363 - Time Delta 12.962 - Time 2025-05-11T16:20:34
# Episode 147 - Step 35257 - Epsilon 0.98677 - Mean Reward 691.53 - Mean Length 231.34 - Mean Loss 0.476 - Mean Q Value 5.432 - Time Delta 13.145 - Time 2025-05-11T16:20:47
# Episode 148 - Step 35708 - Epsilon 0.98668 - Mean Reward 695.07 - Mean Length 227.4 - Mean Loss 0.477 - Mean Q Value 5.5 - Time Delta 10.108 - Time 2025-05-11T16:20:57
# Episode 149 - Step 36610 - Epsilon 0.98659 - Mean Reward 694.06 - Mean Length 232.83 - Mean Loss 0.479 - Mean Q Value 5.566 - Time Delta 19.322 - Time 2025-05-11T16:21:16
# Episode 150 - Step 36938 - Epsilon 0.9865 - Mean Reward 701.86 - Mean Length 235.68 - Mean Loss 0.481 - Mean Q Value 5.635 - Time Delta 7.444 - Time 2025-05-11T16:21:24
# Episode 151 - Step 37255 - Epsilon 0.98641 - Mean Reward 697.36 - Mean Length 229.5 - Mean Loss 0.482 - Mean Q Value 5.698 - Time Delta 7.139 - Time 2025-05-11T16:21:31
# Episode 152 - Step 37412 - Epsilon 0.98632 - Mean Reward 697.54 - Mean Length 230.05 - Mean Loss 0.484 - Mean Q Value 5.764 - Time Delta 3.623 - Time 2025-05-11T16:21:34
# Episode 153 - Step 37520 - Epsilon 0.98623 - Mean Reward 701.24 - Mean Length 230.73 - Mean Loss 0.484 - Mean Q Value 5.831 - Time Delta 2.572 - Time 2025-05-11T16:21:37
# Episode 154 - Step 37918 - Epsilon 0.98614 - Mean Reward 705.08 - Mean Length 233.6 - Mean Loss 0.485 - Mean Q Value 5.894 - Time Delta 8.783 - Time 2025-05-11T16:21:46
# Episode 155 - Step 38247 - Epsilon 0.98605 - Mean Reward 708.95 - Mean Length 235.82 - Mean Loss 0.485 - Mean Q Value 5.955 - Time Delta 7.31 - Time 2025-05-11T16:21:53
# Episode 156 - Step 38425 - Epsilon 0.98596 - Mean Reward 710.02 - Mean Length 236.42 - Mean Loss 0.485 - Mean Q Value 6.016 - Time Delta 4.122 - Time 2025-05-11T16:21:57
# Episode 157 - Step 38772 - Epsilon 0.98587 - Mean Reward 712.45 - Mean Length 238.18 - Mean Loss 0.487 - Mean Q Value 6.075 - Time Delta 7.772 - Time 2025-05-11T16:22:05
# Episode 158 - Step 38812 - Epsilon 0.98578 - Mean Reward 712.45 - Mean Length 238.18 - Mean Loss 0.489 - Mean Q Value 6.132 - Time Delta 1.112 - Time 2025-05-11T16:22:06
# Episode 159 - Step 38928 - Epsilon 0.98569 - Mean Reward 706.11 - Mean Length 231.99 - Mean Loss 0.492 - Mean Q Value 6.194 - Time Delta 2.736 - Time 2025-05-11T16:22:09
# Episode 160 - Step 39035 - Epsilon 0.9856 - Mean Reward 706.5 - Mean Length 231.84 - Mean Loss 0.495 - Mean Q Value 6.254 - Time Delta 2.663 - Time 2025-05-11T16:22:11
# Episode 161 - Step 39214 - Epsilon 0.98551 - Mean Reward 706.58 - Mean Length 231.44 - Mean Loss 0.495 - Mean Q Value 6.311 - Time Delta 4.109 - Time 2025-05-11T16:22:16
# Episode 162 - Step 39320 - Epsilon 0.98542 - Mean Reward 705.16 - Mean Length 229.48 - Mean Loss 0.496 - Mean Q Value 6.371 - Time Delta 2.544 - Time 2025-05-11T16:22:18
# Episode 163 - Step 39431 - Epsilon 0.98533 - Mean Reward 708.79 - Mean Length 230.19 - Mean Loss 0.496 - Mean Q Value 6.429 - Time Delta 2.618 - Time 2025-05-11T16:22:21
# Episode 164 - Step 39535 - Epsilon 0.98524 - Mean Reward 708.86 - Mean Length 230.22 - Mean Loss 0.496 - Mean Q Value 6.491 - Time Delta 2.49 - Time 2025-05-11T16:22:23
# Episode 165 - Step 39692 - Epsilon 0.98515 - Mean Reward 713.0 - Mean Length 231.35 - Mean Loss 0.497 - Mean Q Value 6.548 - Time Delta 3.817 - Time 2025-05-11T16:22:27
# Episode 166 - Step 40000 - Epsilon 0.98506 - Mean Reward 711.59 - Mean Length 226.75 - Mean Loss 0.497 - Mean Q Value 6.608 - Time Delta 6.928 - Time 2025-05-11T16:22:34
# Episode 167 - Step 40518 - Epsilon 0.98497 - Mean Reward 718.03 - Mean Length 230.23 - Mean Loss 0.501 - Mean Q Value 6.688 - Time Delta 11.287 - Time 2025-05-11T16:22:45
# Episode 168 - Step 40804 - Epsilon 0.98488 - Mean Reward 715.52 - Mean Length 231.01 - Mean Loss 0.503 - Mean Q Value 6.766 - Time Delta 6.438 - Time 2025-05-11T16:22:52
# Episode 169 - Step 41079 - Epsilon 0.98479 - Mean Reward 723.49 - Mean Length 233.36 - Mean Loss 0.504 - Mean Q Value 6.842 - Time Delta 5.935 - Time 2025-05-11T16:22:58
# Episode 170 - Step 41119 - Epsilon 0.9847 - Mean Reward 723.49 - Mean Length 233.36 - Mean Loss 0.504 - Mean Q Value 6.927 - Time Delta 1.234 - Time 2025-05-11T16:22:59
# Episode 171 - Step 41598 - Epsilon 0.98461 - Mean Reward 723.91 - Mean Length 236.45 - Mean Loss 0.505 - Mean Q Value 7.0 - Time Delta 9.813 - Time 2025-05-11T16:23:09
# Episode 172 - Step 42090 - Epsilon 0.98452 - Mean Reward 728.85 - Mean Length 240.97 - Mean Loss 0.508 - Mean Q Value 7.068 - Time Delta 18.762 - Time 2025-05-11T16:23:27
# Episode 173 - Step 42193 - Epsilon 0.98443 - Mean Reward 728.56 - Mean Length 236.81 - Mean Loss 0.51 - Mean Q Value 7.138 - Time Delta 2.497 - Time 2025-05-11T16:23:30
# Episode 174 - Step 42477 - Epsilon 0.98434 - Mean Reward 732.43 - Mean Length 238.57 - Mean Loss 0.511 - Mean Q Value 7.206 - Time Delta 6.231 - Time 2025-05-11T16:23:36
# Episode 175 - Step 42521 - Epsilon 0.98425 - Mean Reward 727.01 - Mean Length 235.06 - Mean Loss 0.512 - Mean Q Value 7.276 - Time Delta 1.174 - Time 2025-05-11T16:23:37
# Episode 176 - Step 42561 - Epsilon 0.98416 - Mean Reward 723.42 - Mean Length 234.3 - Mean Loss 0.514 - Mean Q Value 7.347 - Time Delta 1.145 - Time 2025-05-11T16:23:38
# Episode 177 - Step 42669 - Epsilon 0.98407 - Mean Reward 727.38 - Mean Length 234.92 - Mean Loss 0.515 - Mean Q Value 7.418 - Time Delta 2.553 - Time 2025-05-11T16:23:41
# Episode 178 - Step 42830 - Epsilon 0.98398 - Mean Reward 727.45 - Mean Length 235.46 - Mean Loss 0.515 - Mean Q Value 7.491 - Time Delta 3.678 - Time 2025-05-11T16:23:45
# Episode 179 - Step 43392 - Epsilon 0.98389 - Mean Reward 731.97 - Mean Length 240.68 - Mean Loss 0.515 - Mean Q Value 7.56 - Time Delta 12.453 - Time 2025-05-11T16:23:57
# Episode 180 - Step 43663 - Epsilon 0.9838 - Mean Reward 729.75 - Mean Length 240.31 - Mean Loss 0.516 - Mean Q Value 7.63 - Time Delta 6.017 - Time 2025-05-11T16:24:03
# Episode 181 - Step 43778 - Epsilon 0.98371 - Mean Reward 725.54 - Mean Length 239.2 - Mean Loss 0.516 - Mean Q Value 7.697 - Time Delta 2.697 - Time 2025-05-11T16:24:06
# Episode 182 - Step 43822 - Epsilon 0.98362 - Mean Reward 720.26 - Mean Length 234.99 - Mean Loss 0.514 - Mean Q Value 7.745 - Time Delta 1.233 - Time 2025-05-11T16:24:07
# Episode 183 - Step 43991 - Epsilon 0.98353 - Mean Reward 720.46 - Mean Length 235.65 - Mean Loss 0.514 - Mean Q Value 7.789 - Time Delta 3.822 - Time 2025-05-11T16:24:11
# Episode 184 - Step 44101 - Epsilon 0.98344 - Mean Reward 716.68 - Mean Length 233.16 - Mean Loss 0.517 - Mean Q Value 7.824 - Time Delta 2.623 - Time 2025-05-11T16:24:14
# Episode 185 - Step 44145 - Epsilon 0.98335 - Mean Reward 709.22 - Mean Length 227.96 - Mean Loss 0.516 - Mean Q Value 7.876 - Time Delta 1.214 - Time 2025-05-11T16:24:15
# Episode 186 - Step 44302 - Epsilon 0.98326 - Mean Reward 713.27 - Mean Length 229.13 - Mean Loss 0.517 - Mean Q Value 7.932 - Time Delta 3.61 - Time 2025-05-11T16:24:18
# Episode 187 - Step 44414 - Epsilon 0.98317 - Mean Reward 716.85 - Mean Length 229.85 - Mean Loss 0.519 - Mean Q Value 7.986 - Time Delta 2.619 - Time 2025-05-11T16:24:21
# Episode 188 - Step 44454 - Epsilon 0.98308 - Mean Reward 712.77 - Mean Length 224.77 - Mean Loss 0.519 - Mean Q Value 8.037 - Time Delta 1.174 - Time 2025-05-11T16:24:22
# Episode 189 - Step 44570 - Epsilon 0.98299 - Mean Reward 706.65 - Mean Length 219.21 - Mean Loss 0.522 - Mean Q Value 8.092 - Time Delta 2.722 - Time 2025-05-11T16:24:25
# Episode 190 - Step 44760 - Epsilon 0.9829 - Mean Reward 708.1 - Mean Length 220.1 - Mean Loss 0.522 - Mean Q Value 8.152 - Time Delta 4.323 - Time 2025-05-11T16:24:29
# Episode 191 - Step 44921 - Epsilon 0.98281 - Mean Reward 708.18 - Mean Length 220.67 - Mean Loss 0.524 - Mean Q Value 8.204 - Time Delta 3.798 - Time 2025-05-11T16:24:33
# Episode 192 - Step 45082 - Epsilon 0.98272 - Mean Reward 708.56 - Mean Length 220.75 - Mean Loss 0.526 - Mean Q Value 8.258 - Time Delta 3.705 - Time 2025-05-11T16:24:37
# Episode 193 - Step 45323 - Epsilon 0.98263 - Mean Reward 704.9 - Mean Length 216.71 - Mean Loss 0.526 - Mean Q Value 8.318 - Time Delta 5.431 - Time 2025-05-11T16:24:42
# Episode 194 - Step 45632 - Epsilon 0.98254 - Mean Reward 710.41 - Mean Length 219.4 - Mean Loss 0.528 - Mean Q Value 8.379 - Time Delta 7.052 - Time 2025-05-11T16:24:49
# Episode 195 - Step 45672 - Epsilon 0.98245 - Mean Reward 702.96 - Mean Length 214.54 - Mean Loss 0.528 - Mean Q Value 8.438 - Time Delta 1.125 - Time 2025-05-11T16:24:50
# Episode 196 - Step 45789 - Epsilon 0.98236 - Mean Reward 702.78 - Mean Length 214.67 - Mean Loss 0.53 - Mean Q Value 8.491 - Time Delta 2.814 - Time 2025-05-11T16:24:53
# Episode 197 - Step 45829 - Epsilon 0.98227 - Mean Reward 692.23 - Mean Length 211.68 - Mean Loss 0.532 - Mean Q Value 8.544 - Time Delta 1.113 - Time 2025-05-11T16:24:54
# Episode 198 - Step 45872 - Epsilon 0.98218 - Mean Reward 688.15 - Mean Length 210.44 - Mean Loss 0.535 - Mean Q Value 8.6 - Time Delta 1.202 - Time 2025-05-11T16:24:55
# Episode 199 - Step 46033 - Epsilon 0.98209 - Mean Reward 686.79 - Mean Length 208.42 - Mean Loss 0.537 - Mean Q Value 8.66 - Time Delta 3.896 - Time 2025-05-11T16:24:59
# Episode 200 - Step 46139 - Epsilon 0.982 - Mean Reward 682.59 - Mean Length 207.26 - Mean Loss 0.539 - Mean Q Value 8.723 - Time Delta 2.517 - Time 2025-05-11T16:25:02
# Episode 201 - Step 46670 - Epsilon 0.98191 - Mean Reward 685.98 - Mean Length 211.0 - Mean Loss 0.54 - Mean Q Value 8.789 - Time Delta 11.6 - Time 2025-05-11T16:25:13
# Episode 202 - Step 46710 - Epsilon 0.98182 - Mean Reward 682.02 - Mean Length 210.36 - Mean Loss 0.545 - Mean Q Value 8.851 - Time Delta 1.137 - Time 2025-05-11T16:25:15
# Episode 203 - Step 46827 - Epsilon 0.98173 - Mean Reward 680.89 - Mean Length 209.73 - Mean Loss 0.547 - Mean Q Value 8.909 - Time Delta 2.767 - Time 2025-05-11T16:25:17
# Episode 204 - Step 46989 - Epsilon 0.98164 - Mean Reward 685.72 - Mean Length 210.95 - Mean Loss 0.549 - Mean Q Value 8.969 - Time Delta 3.727 - Time 2025-05-11T16:25:21
# Episode 205 - Step 47029 - Epsilon 0.98155 - Mean Reward 685.77 - Mean Length 210.92 - Mean Loss 0.551 - Mean Q Value 9.032 - Time Delta 1.113 - Time 2025-05-11T16:25:22
# Episode 206 - Step 47444 - Epsilon 0.98146 - Mean Reward 687.97 - Mean Length 211.19 - Mean Loss 0.553 - Mean Q Value 9.099 - Time Delta 9.151 - Time 2025-05-11T16:25:31
# Episode 207 - Step 47726 - Epsilon 0.98137 - Mean Reward 685.0 - Mean Length 211.87 - Mean Loss 0.554 - Mean Q Value 9.166 - Time Delta 6.371 - Time 2025-05-11T16:25:38
# Episode 208 - Step 47961 - Epsilon 0.98128 - Mean Reward 669.82 - Mean Length 206.95 - Mean Loss 0.557 - Mean Q Value 9.228 - Time Delta 5.273 - Time 2025-05-11T16:25:43
# Episode 209 - Step 48180 - Epsilon 0.98119 - Mean Reward 674.24 - Mean Length 207.99 - Mean Loss 0.56 - Mean Q Value 9.294 - Time Delta 4.92 - Time 2025-05-11T16:25:48
# Episode 210 - Step 48220 - Epsilon 0.9811 - Mean Reward 674.24 - Mean Length 207.99 - Mean Loss 0.56 - Mean Q Value 9.372 - Time Delta 1.287 - Time 2025-05-11T16:25:49
# Episode 211 - Step 48323 - Epsilon 0.98101 - Mean Reward 667.51 - Mean Length 205.37 - Mean Loss 0.562 - Mean Q Value 9.442 - Time Delta 2.437 - Time 2025-05-11T16:25:52
# Episode 212 - Step 48363 - Epsilon 0.98092 - Mean Reward 663.82 - Mean Length 204.58 - Mean Loss 0.564 - Mean Q Value 9.505 - Time Delta 1.121 - Time 2025-05-11T16:25:53
# Episode 213 - Step 48403 - Epsilon 0.98083 - Mean Reward 659.93 - Mean Length 203.97 - Mean Loss 0.564 - Mean Q Value 9.566 - Time Delta 1.089 - Time 2025-05-11T16:25:54
# Episode 214 - Step 48743 - Epsilon 0.98074 - Mean Reward 662.38 - Mean Length 205.19 - Mean Loss 0.567 - Mean Q Value 9.628 - Time Delta 7.538 - Time 2025-05-11T16:26:01
# Episode 215 - Step 49021 - Epsilon 0.98065 - Mean Reward 667.77 - Mean Length 207.57 - Mean Loss 0.57 - Mean Q Value 9.694 - Time Delta 6.128 - Time 2025-05-11T16:26:08
# Episode 216 - Step 49295 - Epsilon 0.98056 - Mean Reward 671.79 - Mean Length 209.33 - Mean Loss 0.57 - Mean Q Value 9.751 - Time Delta 6.108 - Time 2025-05-11T16:26:14
# Episode 217 - Step 49416 - Epsilon 0.98047 - Mean Reward 671.28 - Mean Length 208.93 - Mean Loss 0.572 - Mean Q Value 9.805 - Time Delta 2.803 - Time 2025-05-11T16:26:16
# Episode 218 - Step 49526 - Epsilon 0.98038 - Mean Reward 669.92 - Mean Length 205.98 - Mean Loss 0.574 - Mean Q Value 9.858 - Time Delta 2.621 - Time 2025-05-11T16:26:19
# Episode 219 - Step 49566 - Epsilon 0.98029 - Mean Reward 665.97 - Mean Length 205.29 - Mean Loss 0.578 - Mean Q Value 9.912 - Time Delta 1.089 - Time 2025-05-11T16:26:20
# Episode 220 - Step 49670 - Epsilon 0.9802 - Mean Reward 669.76 - Mean Length 205.93 - Mean Loss 0.581 - Mean Q Value 9.969 - Time Delta 2.406 - Time 2025-05-11T16:26:23
# Episode 221 - Step 49827 - Epsilon 0.98011 - Mean Reward 666.99 - Mean Length 204.53 - Mean Loss 0.584 - Mean Q Value 10.03 - Time Delta 3.608 - Time 2025-05-11T16:26:26
# Episode 222 - Step 49988 - Epsilon 0.98002 - Mean Reward 671.03 - Mean Length 205.74 - Mean Loss 0.586 - Mean Q Value 10.097 - Time Delta 3.729 - Time 2025-05-11T16:26:30
# Episode 223 - Step 50358 - Epsilon 0.97993 - Mean Reward 672.08 - Mean Length 208.26 - Mean Loss 0.591 - Mean Q Value 10.18 - Time Delta 8.175 - Time 2025-05-11T16:26:38
# Episode 224 - Step 50881 - Epsilon 0.97984 - Mean Reward 678.29 - Mean Length 212.43 - Mean Loss 0.595 - Mean Q Value 10.265 - Time Delta 11.428 - Time 2025-05-11T16:26:49
# Episode 225 - Step 51004 - Epsilon 0.97975 - Mean Reward 677.22 - Mean Length 211.49 - Mean Loss 0.597 - Mean Q Value 10.341 - Time Delta 2.857 - Time 2025-05-11T16:26:52
# Episode 226 - Step 51048 - Epsilon 0.97966 - Mean Reward 677.14 - Mean Length 211.53 - Mean Loss 0.6 - Mean Q Value 10.427 - Time Delta 1.178 - Time 2025-05-11T16:26:54
# Episode 227 - Step 51212 - Epsilon 0.97957 - Mean Reward 677.23 - Mean Length 212.19 - Mean Loss 0.606 - Mean Q Value 10.513 - Time Delta 3.739 - Time 2025-05-11T16:26:57
# Episode 228 - Step 51252 - Epsilon 0.97948 - Mean Reward 677.23 - Mean Length 212.19 - Mean Loss 0.603 - Mean Q Value 10.587 - Time Delta 1.147 - Time 2025-05-11T16:26:58
# Episode 229 - Step 51726 - Epsilon 0.97939 - Mean Reward 684.67 - Mean Length 216.53 - Mean Loss 0.6 - Mean Q Value 10.643 - Time Delta 10.581 - Time 2025-05-11T16:27:09
# Episode 230 - Step 51766 - Epsilon 0.9793 - Mean Reward 684.67 - Mean Length 216.53 - Mean Loss 0.595 - Mean Q Value 10.687 - Time Delta 1.092 - Time 2025-05-11T16:27:10
# Episode 231 - Step 51810 - Epsilon 0.97921 - Mean Reward 674.36 - Mean Length 211.77 - Mean Loss 0.594 - Mean Q Value 10.746 - Time Delta 1.216 - Time 2025-05-11T16:27:11
# Episode 232 - Step 51972 - Epsilon 0.97912 - Mean Reward 674.81 - Mean Length 212.21 - Mean Loss 0.594 - Mean Q Value 10.809 - Time Delta 3.701 - Time 2025-05-11T16:27:15
# Episode 233 - Step 52016 - Epsilon 0.97903 - Mean Reward 670.69 - Mean Length 211.02 - Mean Loss 0.594 - Mean Q Value 10.874 - Time Delta 1.169 - Time 2025-05-11T16:27:16
# Episode 234 - Step 52397 - Epsilon 0.97894 - Mean Reward 667.74 - Mean Length 211.92 - Mean Loss 0.595 - Mean Q Value 10.933 - Time Delta 8.372 - Time 2025-05-11T16:27:25
# Episode 235 - Step 52516 - Epsilon 0.97885 - Mean Reward 667.62 - Mean Length 212.1 - Mean Loss 0.597 - Mean Q Value 10.979 - Time Delta 2.748 - Time 2025-05-11T16:27:27
# Episode 236 - Step 52683 - Epsilon 0.97876 - Mean Reward 650.9 - Mean Length 208.31 - Mean Loss 0.599 - Mean Q Value 11.03 - Time Delta 3.803 - Time 2025-05-11T16:27:31
# Episode 237 - Step 52840 - Epsilon 0.97867 - Mean Reward 646.95 - Mean Length 207.31 - Mean Loss 0.6 - Mean Q Value 11.078 - Time Delta 3.661 - Time 2025-05-11T16:27:35
# Episode 238 - Step 53535 - Epsilon 0.97858 - Mean Reward 650.02 - Mean Length 212.64 - Mean Loss 0.602 - Mean Q Value 11.127 - Time Delta 15.02 - Time 2025-05-11T16:27:50
# Episode 239 - Step 53947 - Epsilon 0.97849 - Mean Reward 657.71 - Mean Length 216.36 - Mean Loss 0.603 - Mean Q Value 11.173 - Time Delta 8.921 - Time 2025-05-11T16:27:59
# Episode 240 - Step 54097 - Epsilon 0.9784 - Mean Reward 658.54 - Mean Length 214.46 - Mean Loss 0.605 - Mean Q Value 11.209 - Time Delta 3.507 - Time 2025-05-11T16:28:02
# Episode 241 - Step 54137 - Epsilon 0.97831 - Mean Reward 650.42 - Mean Length 212.96 - Mean Loss 0.607 - Mean Q Value 11.254 - Time Delta 1.105 - Time 2025-05-11T16:28:03
# Episode 242 - Step 54300 - Epsilon 0.97822 - Mean Reward 654.46 - Mean Length 214.19 - Mean Loss 0.606 - Mean Q Value 11.285 - Time Delta 3.773 - Time 2025-05-11T16:28:07
# Episode 243 - Step 54502 - Epsilon 0.9781299999999999 - Mean Reward 649.9 - Mean Length 208.33 - Mean Loss 0.608 - Mean Q Value 11.331 - Time Delta 4.625 - Time 2025-05-11T16:28:12
# Episode 244 - Step 54608 - Epsilon 0.97804 - Mean Reward 649.07 - Mean Length 206.66 - Mean Loss 0.609 - Mean Q Value 11.382 - Time Delta 2.655 - Time 2025-05-11T16:28:14
# Episode 245 - Step 54763 - Epsilon 0.97795 - Mean Reward 648.88 - Mean Length 207.13 - Mean Loss 0.611 - Mean Q Value 11.433 - Time Delta 3.55 - Time 2025-05-11T16:28:18
# Episode 246 - Step 54803 - Epsilon 0.97786 - Mean Reward 641.57 - Mean Length 201.57 - Mean Loss 0.614 - Mean Q Value 11.454 - Time Delta 1.108 - Time 2025-05-11T16:28:19
# Episode 247 - Step 54847 - Epsilon 0.97777 - Mean Reward 628.96 - Mean Length 195.9 - Mean Loss 0.616 - Mean Q Value 11.493 - Time Delta 1.408 - Time 2025-05-11T16:28:20
# Episode 248 - Step 55178 - Epsilon 0.97768 - Mean Reward 626.45 - Mean Length 194.7 - Mean Loss 0.617 - Mean Q Value 11.54 - Time Delta 7.334 - Time 2025-05-11T16:28:28
# Episode 249 - Step 55349 - Epsilon 0.97759 - Mean Reward 623.77 - Mean Length 187.39 - Mean Loss 0.619 - Mean Q Value 11.587 - Time Delta 3.847 - Time 2025-05-11T16:28:32
# Episode 250 - Step 55464 - Epsilon 0.9775 - Mean Reward 619.52 - Mean Length 185.26 - Mean Loss 0.621 - Mean Q Value 11.638 - Time Delta 2.708 - Time 2025-05-11T16:28:34
# Episode 251 - Step 55567 - Epsilon 0.97741 - Mean Reward 618.55 - Mean Length 183.12 - Mean Loss 0.623 - Mean Q Value 11.699 - Time Delta 2.438 - Time 2025-05-11T16:28:37
# Episode 252 - Step 55734 - Epsilon 0.97732 - Mean Reward 620.29 - Mean Length 183.22 - Mean Loss 0.625 - Mean Q Value 11.756 - Time Delta 3.852 - Time 2025-05-11T16:28:41
# Episode 253 - Step 55849 - Epsilon 0.97723 - Mean Reward 620.22 - Mean Length 183.29 - Mean Loss 0.627 - Mean Q Value 11.811 - Time Delta 2.691 - Time 2025-05-11T16:28:43
# Episode 254 - Step 55889 - Epsilon 0.97714 - Mean Reward 612.5 - Mean Length 179.71 - Mean Loss 0.63 - Mean Q Value 11.875 - Time Delta 1.135 - Time 2025-05-11T16:28:44
# Episode 255 - Step 56408 - Epsilon 0.97705 - Mean Reward 612.09 - Mean Length 181.61 - Mean Loss 0.633 - Mean Q Value 11.932 - Time Delta 11.555 - Time 2025-05-11T16:28:56
# Episode 256 - Step 56448 - Epsilon 0.97696 - Mean Reward 607.2 - Mean Length 180.23 - Mean Loss 0.634 - Mean Q Value 11.989 - Time Delta 1.124 - Time 2025-05-11T16:28:57
# Episode 257 - Step 56569 - Epsilon 0.97687 - Mean Reward 602.96 - Mean Length 177.97 - Mean Loss 0.635 - Mean Q Value 12.047 - Time Delta 2.856 - Time 2025-05-11T16:29:00
# Episode 258 - Step 56609 - Epsilon 0.97678 - Mean Reward 602.96 - Mean Length 177.97 - Mean Loss 0.636 - Mean Q Value 12.108 - Time Delta 1.11 - Time 2025-05-11T16:29:01
# Episode 259 - Step 56779 - Epsilon 0.97669 - Mean Reward 603.37 - Mean Length 178.51 - Mean Loss 0.638 - Mean Q Value 12.172 - Time Delta 3.966 - Time 2025-05-11T16:29:05
# Episode 260 - Step 57205 - Epsilon 0.9766 - Mean Reward 609.84 - Mean Length 181.7 - Mean Loss 0.638 - Mean Q Value 12.233 - Time Delta 9.427 - Time 2025-05-11T16:29:14
# Episode 261 - Step 57372 - Epsilon 0.97651 - Mean Reward 608.1 - Mean Length 181.58 - Mean Loss 0.641 - Mean Q Value 12.3 - Time Delta 3.87 - Time 2025-05-11T16:29:18
# Episode 262 - Step 57842 - Epsilon 0.97642 - Mean Reward 612.64 - Mean Length 185.22 - Mean Loss 0.643 - Mean Q Value 12.36 - Time Delta 10.351 - Time 2025-05-11T16:29:29
# Episode 263 - Step 57945 - Epsilon 0.97633 - Mean Reward 612.84 - Mean Length 185.14 - Mean Loss 0.647 - Mean Q Value 12.418 - Time Delta 2.675 - Time 2025-05-11T16:29:31
# Episode 264 - Step 58184 - Epsilon 0.97624 - Mean Reward 616.8 - Mean Length 186.49 - Mean Loss 0.649 - Mean Q Value 12.48 - Time Delta 5.325 - Time 2025-05-11T16:29:37
# Episode 265 - Step 58287 - Epsilon 0.97615 - Mean Reward 616.71 - Mean Length 185.95 - Mean Loss 0.654 - Mean Q Value 12.537 - Time Delta 2.455 - Time 2025-05-11T16:29:39
# Episode 266 - Step 58327 - Epsilon 0.97606 - Mean Reward 611.2 - Mean Length 183.27 - Mean Loss 0.66 - Mean Q Value 12.591 - Time Delta 1.111 - Time 2025-05-11T16:29:40
# Episode 267 - Step 58439 - Epsilon 0.97597 - Mean Reward 604.58 - Mean Length 179.21 - Mean Loss 0.658 - Mean Q Value 12.632 - Time Delta 2.637 - Time 2025-05-11T16:29:43
# Episode 268 - Step 58479 - Epsilon 0.97588 - Mean Reward 599.03 - Mean Length 176.75 - Mean Loss 0.659 - Mean Q Value 12.663 - Time Delta 1.111 - Time 2025-05-11T16:29:44
# Episode 269 - Step 58583 - Epsilon 0.97579 - Mean Reward 595.02 - Mean Length 175.04 - Mean Loss 0.663 - Mean Q Value 12.707 - Time Delta 2.474 - Time 2025-05-11T16:29:46
# Episode 270 - Step 58728 - Epsilon 0.9757 - Mean Reward 598.58 - Mean Length 176.09 - Mean Loss 0.665 - Mean Q Value 12.747 - Time Delta 3.349 - Time 2025-05-11T16:29:50
# Episode 271 - Step 59135 - Epsilon 0.97561 - Mean Reward 605.61 - Mean Length 175.37 - Mean Loss 0.666 - Mean Q Value 12.794 - Time Delta 8.909 - Time 2025-05-11T16:29:59
# Episode 272 - Step 59291 - Epsilon 0.97552 - Mean Reward 604.72 - Mean Length 172.01 - Mean Loss 0.669 - Mean Q Value 12.841 - Time Delta 3.599 - Time 2025-05-11T16:30:02
# Episode 273 - Step 59331 - Epsilon 0.97543 - Mean Reward 600.89 - Mean Length 171.38 - Mean Loss 0.67 - Mean Q Value 12.881 - Time Delta 1.118 - Time 2025-05-11T16:30:03
# Episode 274 - Step 59371 - Epsilon 0.97534 - Mean Reward 593.05 - Mean Length 168.94 - Mean Loss 0.673 - Mean Q Value 12.937 - Time Delta 1.108 - Time 2025-05-11T16:30:05
# Episode 275 - Step 59411 - Epsilon 0.97525 - Mean Reward 593.13 - Mean Length 168.9 - Mean Loss 0.68 - Mean Q Value 12.987 - Time Delta 1.112 - Time 2025-05-11T16:30:06
# Episode 276 - Step 59742 - Epsilon 0.97516 - Mean Reward 600.98 - Mean Length 171.81 - Mean Loss 0.681 - Mean Q Value 13.037 - Time Delta 7.447 - Time 2025-05-11T16:30:13
# Episode 277 - Step 60120 - Epsilon 0.97507 - Mean Reward 602.23 - Mean Length 174.51 - Mean Loss 0.684 - Mean Q Value 13.09 - Time Delta 9.162 - Time 2025-05-11T16:30:22
# Episode 278 - Step 60160 - Epsilon 0.97498 - Mean Reward 598.19 - Mean Length 173.3 - Mean Loss 0.69 - Mean Q Value 13.162 - Time Delta 1.128 - Time 2025-05-11T16:30:23
# Episode 279 - Step 60444 - Epsilon 0.97489 - Mean Reward 598.89 - Mean Length 170.52 - Mean Loss 0.693 - Mean Q Value 13.23 - Time Delta 6.483 - Time 2025-05-11T16:30:30
# Episode 280 - Step 60870 - Epsilon 0.9748 - Mean Reward 600.91 - Mean Length 172.07 - Mean Loss 0.696 - Mean Q Value 13.294 - Time Delta 9.874 - Time 2025-05-11T16:30:40
# Episode 281 - Step 61034 - Epsilon 0.97471 - Mean Reward 601.21 - Mean Length 172.56 - Mean Loss 0.701 - Mean Q Value 13.361 - Time Delta 3.966 - Time 2025-05-11T16:30:44
# Episode 282 - Step 61147 - Epsilon 0.97462 - Mean Reward 605.18 - Mean Length 173.25 - Mean Loss 0.705 - Mean Q Value 13.434 - Time Delta 2.819 - Time 2025-05-11T16:30:47
# ...
# Episode 9914 - Step 1940195 - Epsilon 0.10774000000000006 - Mean Reward 1028.82 - Mean Length 179.01 - Mean Loss 1.09 - Mean Q Value 57.65 - Time Delta 5.151 - Time 2025-05-12T04:56:49
# Episode 9915 - Step 1940293 - Epsilon 0.10764999999999991 - Mean Reward 1024.59 - Mean Length 178.38 - Mean Loss 1.092 - Mean Q Value 57.641 - Time Delta 2.601 - Time 2025-05-12T04:56:51
# Episode 9916 - Step 1940493 - Epsilon 0.10755999999999999 - Mean Reward 1027.37 - Mean Length 178.72 - Mean Loss 1.095 - Mean Q Value 57.612 - Time Delta 4.945 - Time 2025-05-12T04:56:56
# Episode 9917 - Step 1940673 - Epsilon 0.10746999999999995 - Mean Reward 1027.46 - Mean Length 178.84 - Mean Loss 1.093 - Mean Q Value 57.6 - Time Delta 4.495 - Time 2025-05-12T04:57:01
# Episode 9918 - Step 1940901 - Epsilon 0.10737999999999992 - Mean Reward 1030.01 - Mean Length 179.51 - Mean Loss 1.096 - Mean Q Value 57.584 - Time Delta 5.589 - Time 2025-05-12T04:57:06
# Episode 9919 - Step 1941118 - Epsilon 0.10729 - Mean Reward 1029.93 - Mean Length 179.45 - Mean Loss 1.095 - Mean Q Value 57.572 - Time Delta 5.313 - Time 2025-05-12T04:57:12
# Episode 9920 - Step 1941252 - Epsilon 0.10719999999999996 - Mean Reward 1029.16 - Mean Length 179.16 - Mean Loss 1.097 - Mean Q Value 57.56 - Time Delta 3.592 - Time 2025-05-12T04:57:15
# Episode 9921 - Step 1941452 - Epsilon 0.10711000000000004 - Mean Reward 1029.19 - Mean Length 179.08 - Mean Loss 1.098 - Mean Q Value 57.536 - Time Delta 4.834 - Time 2025-05-12T04:57:20
# Episode 9922 - Step 1941492 - Epsilon 0.10702 - Mean Reward 1025.74 - Mean Length 177.98 - Mean Loss 1.097 - Mean Q Value 57.529 - Time Delta 1.281 - Time 2025-05-12T04:57:21
# Episode 9923 - Step 1941700 - Epsilon 0.10692999999999997 - Mean Reward 1028.49 - Mean Length 178.43 - Mean Loss 1.094 - Mean Q Value 57.504 - Time Delta 5.055 - Time 2025-05-12T04:57:26
# Episode 9924 - Step 1941937 - Epsilon 0.10684000000000005 - Mean Reward 1028.58 - Mean Length 178.35 - Mean Loss 1.095 - Mean Q Value 57.489 - Time Delta 5.706 - Time 2025-05-12T04:57:32
# Episode 9925 - Step 1942100 - Epsilon 0.1067499999999999 - Mean Reward 1032.6 - Mean Length 178.42 - Mean Loss 1.094 - Mean Q Value 57.478 - Time Delta 4.075 - Time 2025-05-12T04:57:36
# Episode 9926 - Step 1942341 - Epsilon 0.10665999999999998 - Mean Reward 1035.2 - Mean Length 179.19 - Mean Loss 1.093 - Mean Q Value 57.464 - Time Delta 5.808 - Time 2025-05-12T04:57:42
# Episode 9927 - Step 1942502 - Epsilon 0.10656999999999994 - Mean Reward 1032.55 - Mean Length 178.61 - Mean Loss 1.092 - Mean Q Value 57.456 - Time Delta 3.982 - Time 2025-05-12T04:57:46
# Episode 9928 - Step 1942680 - Epsilon 0.10648000000000002 - Mean Reward 1029.78 - Mean Length 178.39 - Mean Loss 1.091 - Mean Q Value 57.44 - Time Delta 4.381 - Time 2025-05-12T04:57:50
# Episode 9929 - Step 1943074 - Epsilon 0.10638999999999998 - Mean Reward 1032.23 - Mean Length 180.72 - Mean Loss 1.089 - Mean Q Value 57.419 - Time Delta 9.257 - Time 2025-05-12T04:58:00
# Episode 9930 - Step 1943238 - Epsilon 0.10629999999999995 - Mean Reward 1036.29 - Mean Length 180.8 - Mean Loss 1.09 - Mean Q Value 57.391 - Time Delta 4.066 - Time 2025-05-12T04:58:04
# Episode 9931 - Step 1943438 - Epsilon 0.10621000000000003 - Mean Reward 1036.4 - Mean Length 180.78 - Mean Loss 1.089 - Mean Q Value 57.379 - Time Delta 4.878 - Time 2025-05-12T04:58:08
# Episode 9932 - Step 1943611 - Epsilon 0.10611999999999999 - Mean Reward 1040.81 - Mean Length 181.47 - Mean Loss 1.09 - Mean Q Value 57.363 - Time Delta 4.292 - Time 2025-05-12T04:58:13
# Episode 9933 - Step 1943823 - Epsilon 0.10603000000000007 - Mean Reward 1045.93 - Mean Length 182.0 - Mean Loss 1.089 - Mean Q Value 57.349 - Time Delta 5.16 - Time 2025-05-12T04:58:18
# Episode 9934 - Step 1943994 - Epsilon 0.10594000000000003 - Mean Reward 1051.48 - Mean Length 183.31 - Mean Loss 1.088 - Mean Q Value 57.339 - Time Delta 4.217 - Time 2025-05-12T04:58:22
# Episode 9935 - Step 1944214 - Epsilon 0.10584999999999989 - Mean Reward 1056.45 - Mean Length 183.92 - Mean Loss 1.089 - Mean Q Value 57.308 - Time Delta 5.319 - Time 2025-05-12T04:58:27
# Episode 9936 - Step 1944497 - Epsilon 0.10575999999999997 - Mean Reward 1063.79 - Mean Length 185.16 - Mean Loss 1.09 - Mean Q Value 57.297 - Time Delta 6.808 - Time 2025-05-12T04:58:34
# Episode 9937 - Step 1944697 - Epsilon 0.10566999999999993 - Mean Reward 1063.64 - Mean Length 185.14 - Mean Loss 1.09 - Mean Q Value 57.284 - Time Delta 5.095 - Time 2025-05-12T04:58:39
# Episode 9938 - Step 1944862 - Epsilon 0.10558000000000001 - Mean Reward 1060.98 - Mean Length 184.79 - Mean Loss 1.089 - Mean Q Value 57.275 - Time Delta 4.072 - Time 2025-05-12T04:58:43
# Episode 9939 - Step 1945025 - Epsilon 0.10548999999999997 - Mean Reward 1058.21 - Mean Length 184.42 - Mean Loss 1.088 - Mean Q Value 57.254 - Time Delta 4.058 - Time 2025-05-12T04:58:47
# Episode 9940 - Step 1945123 - Epsilon 0.10539999999999994 - Mean Reward 1051.32 - Mean Length 183.4 - Mean Loss 1.089 - Mean Q Value 57.237 - Time Delta 2.586 - Time 2025-05-12T04:58:50
# Episode 9941 - Step 1945352 - Epsilon 0.10531000000000001 - Mean Reward 1051.24 - Mean Length 183.63 - Mean Loss 1.088 - Mean Q Value 57.216 - Time Delta 5.493 - Time 2025-05-12T04:58:56
# Episode 9942 - Step 1945513 - Epsilon 0.10521999999999998 - Mean Reward 1051.26 - Mean Length 183.63 - Mean Loss 1.088 - Mean Q Value 57.183 - Time Delta 3.976 - Time 2025-05-12T04:59:00
# Episode 9943 - Step 1945611 - Epsilon 0.10513000000000006 - Mean Reward 1051.16 - Mean Length 183.04 - Mean Loss 1.091 - Mean Q Value 57.159 - Time Delta 2.554 - Time 2025-05-12T04:59:02
# Episode 9944 - Step 1945928 - Epsilon 0.10504000000000002 - Mean Reward 1050.91 - Mean Length 184.15 - Mean Loss 1.092 - Mean Q Value 57.137 - Time Delta 7.499 - Time 2025-05-12T04:59:10
# Episode 9945 - Step 1946091 - Epsilon 0.10494999999999999 - Mean Reward 1050.94 - Mean Length 184.05 - Mean Loss 1.092 - Mean Q Value 57.126 - Time Delta 4.07 - Time 2025-05-12T04:59:14
# Episode 9946 - Step 1946294 - Epsilon 0.10485999999999995 - Mean Reward 1056.93 - Mean Length 184.33 - Mean Loss 1.09 - Mean Q Value 57.098 - Time Delta 4.92 - Time 2025-05-12T04:59:19
# Episode 9947 - Step 1946457 - Epsilon 0.10476999999999992 - Mean Reward 1059.78 - Mean Length 183.27 - Mean Loss 1.089 - Mean Q Value 57.086 - Time Delta 4.022 - Time 2025-05-12T04:59:23
# Episode 9948 - Step 1946560 - Epsilon 0.10468 - Mean Reward 1052.73 - Mean Length 182.27 - Mean Loss 1.092 - Mean Q Value 57.076 - Time Delta 2.695 - Time 2025-05-12T04:59:25
# Episode 9949 - Step 1946721 - Epsilon 0.10458999999999996 - Mean Reward 1052.79 - Mean Length 181.95 - Mean Loss 1.09 - Mean Q Value 57.073 - Time Delta 3.943 - Time 2025-05-12T04:59:29
# Episode 9950 - Step 1946974 - Epsilon 0.10450000000000004 - Mean Reward 1052.72 - Mean Length 182.38 - Mean Loss 1.094 - Mean Q Value 57.061 - Time Delta 6.062 - Time 2025-05-12T04:59:35
# Episode 9951 - Step 1947174 - Epsilon 0.10441 - Mean Reward 1055.5 - Mean Length 182.72 - Mean Loss 1.095 - Mean Q Value 57.045 - Time Delta 4.883 - Time 2025-05-12T04:59:40
# Episode 9952 - Step 1947214 - Epsilon 0.10431999999999997 - Mean Reward 1050.23 - Mean Length 181.38 - Mean Loss 1.101 - Mean Q Value 57.03 - Time Delta 1.207 - Time 2025-05-12T04:59:41
# Episode 9953 - Step 1947254 - Epsilon 0.10423000000000004 - Mean Reward 1039.24 - Mean Length 179.76 - Mean Loss 1.101 - Mean Q Value 57.018 - Time Delta 1.24 - Time 2025-05-12T04:59:43
# Episode 9954 - Step 1947417 - Epsilon 0.10414000000000001 - Mean Reward 1043.26 - Mean Length 179.83 - Mean Loss 1.104 - Mean Q Value 57.013 - Time Delta 4.029 - Time 2025-05-12T04:59:47
# Episode 9955 - Step 1947578 - Epsilon 0.10404999999999998 - Mean Reward 1040.67 - Mean Length 179.19 - Mean Loss 1.107 - Mean Q Value 57.024 - Time Delta 4.232 - Time 2025-05-12T04:59:51
# Episode 9956 - Step 1947802 - Epsilon 0.10395999999999994 - Mean Reward 1040.77 - Mean Length 179.36 - Mean Loss 1.105 - Mean Q Value 57.034 - Time Delta 5.374 - Time 2025-05-12T04:59:56
# Episode 9957 - Step 1948035 - Epsilon 0.1038699999999999 - Mean Reward 1040.79 - Mean Length 179.58 - Mean Loss 1.101 - Mean Q Value 57.039 - Time Delta 5.593 - Time 2025-05-12T05:00:02
# Episode 9958 - Step 1948264 - Epsilon 0.10377999999999998 - Mean Reward 1043.42 - Mean Length 180.02 - Mean Loss 1.096 - Mean Q Value 57.04 - Time Delta 5.505 - Time 2025-05-12T05:00:07
# Episode 9959 - Step 1948512 - Epsilon 0.10368999999999995 - Mean Reward 1043.2 - Mean Length 180.49 - Mean Loss 1.09 - Mean Q Value 57.043 - Time Delta 5.891 - Time 2025-05-12T05:00:13
# Episode 9960 - Step 1948731 - Epsilon 0.10360000000000003 - Mean Reward 1043.27 - Mean Length 180.46 - Mean Loss 1.087 - Mean Q Value 57.036 - Time Delta 5.33 - Time 2025-05-12T05:00:19
# Episode 9961 - Step 1948845 - Epsilon 0.10350999999999999 - Mean Reward 1036.02 - Mean Length 179.33 - Mean Loss 1.085 - Mean Q Value 57.026 - Time Delta 2.905 - Time 2025-05-12T05:00:22
# Episode 9962 - Step 1949045 - Epsilon 0.10341999999999996 - Mean Reward 1043.28 - Mean Length 180.21 - Mean Loss 1.085 - Mean Q Value 57.022 - Time Delta 4.874 - Time 2025-05-12T05:00:26
# Episode 9963 - Step 1949245 - Epsilon 0.10333000000000003 - Mean Reward 1043.25 - Mean Length 180.11 - Mean Loss 1.08 - Mean Q Value 57.031 - Time Delta 4.91 - Time 2025-05-12T05:00:31
# Episode 9964 - Step 1949449 - Epsilon 0.10324 - Mean Reward 1045.95 - Mean Length 180.54 - Mean Loss 1.079 - Mean Q Value 57.03 - Time Delta 4.962 - Time 2025-05-12T05:00:36
# Episode 9965 - Step 1949657 - Epsilon 0.10314999999999996 - Mean Reward 1046.0 - Mean Length 180.01 - Mean Loss 1.075 - Mean Q Value 57.031 - Time Delta 5.056 - Time 2025-05-12T05:00:41
# Episode 9966 - Step 1949697 - Epsilon 0.10305999999999993 - Mean Reward 1035.12 - Mean Length 178.32 - Mean Loss 1.07 - Mean Q Value 57.034 - Time Delta 1.237 - Time 2025-05-12T05:00:43
# Episode 9967 - Step 1949879 - Epsilon 0.10297 - Mean Reward 1031.78 - Mean Length 178.38 - Mean Loss 1.067 - Mean Q Value 57.037 - Time Delta 4.453 - Time 2025-05-12T05:00:47
# Episode 9968 - Step 1950105 - Epsilon 0.10287999999999997 - Mean Reward 1031.63 - Mean Length 178.63 - Mean Loss 1.067 - Mean Q Value 57.033 - Time Delta 5.51 - Time 2025-05-12T05:00:53
# Episode 9969 - Step 1950348 - Epsilon 0.10278999999999994 - Mean Reward 1034.34 - Mean Length 179.1 - Mean Loss 1.07 - Mean Q Value 57.038 - Time Delta 5.864 - Time 2025-05-12T05:00:58
# Episode 9970 - Step 1950577 - Epsilon 0.10270000000000001 - Mean Reward 1034.39 - Mean Length 179.39 - Mean Loss 1.073 - Mean Q Value 57.028 - Time Delta 5.494 - Time 2025-05-12T05:01:04
# Episode 9971 - Step 1950777 - Epsilon 0.10260999999999998 - Mean Reward 1034.39 - Mean Length 179.39 - Mean Loss 1.072 - Mean Q Value 57.018 - Time Delta 4.838 - Time 2025-05-12T05:01:09
# Episode 9972 - Step 1951021 - Epsilon 0.10252000000000006 - Mean Reward 1034.41 - Mean Length 179.24 - Mean Loss 1.07 - Mean Q Value 57.015 - Time Delta 5.92 - Time 2025-05-12T05:01:15
# Episode 9973 - Step 1951227 - Epsilon 0.10243000000000002 - Mean Reward 1034.54 - Mean Length 178.51 - Mean Loss 1.069 - Mean Q Value 57.014 - Time Delta 5.239 - Time 2025-05-12T05:01:20
# Episode 9974 - Step 1951436 - Epsilon 0.10233999999999999 - Mean Reward 1039.55 - Mean Length 178.97 - Mean Loss 1.067 - Mean Q Value 57.018 - Time Delta 5.033 - Time 2025-05-12T05:01:25
# Episode 9975 - Step 1951692 - Epsilon 0.10224999999999995 - Mean Reward 1039.43 - Mean Length 179.53 - Mean Loss 1.066 - Mean Q Value 57.015 - Time Delta 6.197 - Time 2025-05-12T05:01:31
# Episode 9976 - Step 1951908 - Epsilon 0.10215999999999992 - Mean Reward 1042.05 - Mean Length 180.08 - Mean Loss 1.067 - Mean Q Value 57.013 - Time Delta 5.196 - Time 2025-05-12T05:01:36
# Episode 9977 - Step 1952109 - Epsilon 0.10207 - Mean Reward 1041.98 - Mean Length 180.16 - Mean Loss 1.066 - Mean Q Value 56.998 - Time Delta 4.91 - Time 2025-05-12T05:01:41
# Episode 9978 - Step 1952272 - Epsilon 0.10197999999999996 - Mean Reward 1036.97 - Mean Length 179.69 - Mean Loss 1.065 - Mean Q Value 56.99 - Time Delta 4.044 - Time 2025-05-12T05:01:45
# Episode 9979 - Step 1952459 - Epsilon 0.10188999999999993 - Mean Reward 1036.93 - Mean Length 179.95 - Mean Loss 1.066 - Mean Q Value 56.965 - Time Delta 4.627 - Time 2025-05-12T05:01:50
# Episode 9980 - Step 1952659 - Epsilon 0.1018 - Mean Reward 1036.97 - Mean Length 179.76 - Mean Loss 1.065 - Mean Q Value 56.936 - Time Delta 4.835 - Time 2025-05-12T05:01:55
# Episode 9981 - Step 1952862 - Epsilon 0.10170999999999997 - Mean Reward 1036.99 - Mean Length 179.79 - Mean Loss 1.065 - Mean Q Value 56.923 - Time Delta 4.912 - Time 2025-05-12T05:02:00
# Episode 9982 - Step 1953174 - Epsilon 0.10162000000000004 - Mean Reward 1041.7 - Mean Length 181.28 - Mean Loss 1.063 - Mean Q Value 56.921 - Time Delta 7.428 - Time 2025-05-12T05:02:07
# Episode 9983 - Step 1953214 - Epsilon 0.10153000000000001 - Mean Reward 1033.52 - Mean Length 180.03 - Mean Loss 1.059 - Mean Q Value 56.928 - Time Delta 1.223 - Time 2025-05-12T05:02:08
# Episode 9984 - Step 1953431 - Epsilon 0.10143999999999997 - Mean Reward 1036.17 - Mean Length 180.6 - Mean Loss 1.059 - Mean Q Value 56.907 - Time Delta 5.309 - Time 2025-05-12T05:02:14
# Episode 9985 - Step 1953638 - Epsilon 0.10134999999999994 - Mean Reward 1038.92 - Mean Length 180.87 - Mean Loss 1.058 - Mean Q Value 56.906 - Time Delta 4.989 - Time 2025-05-12T05:02:19
# Episode 9986 - Step 1953838 - Epsilon 0.1012599999999999 - Mean Reward 1049.76 - Mean Length 182.47 - Mean Loss 1.061 - Mean Q Value 56.875 - Time Delta 4.895 - Time 2025-05-12T05:02:23
# Episode 9987 - Step 1953878 - Epsilon 0.10116999999999998 - Mean Reward 1045.84 - Mean Length 180.66 - Mean Loss 1.055 - Mean Q Value 56.874 - Time Delta 1.237 - Time 2025-05-12T05:02:25
# Episode 9988 - Step 1954039 - Epsilon 0.10107999999999995 - Mean Reward 1048.21 - Mean Length 180.68 - Mean Loss 1.053 - Mean Q Value 56.867 - Time Delta 3.993 - Time 2025-05-12T05:02:29
# Episode 9989 - Step 1954239 - Epsilon 0.10099000000000002 - Mean Reward 1048.28 - Mean Length 180.39 - Mean Loss 1.049 - Mean Q Value 56.864 - Time Delta 4.879 - Time 2025-05-12T05:02:34
# Episode 9990 - Step 1954443 - Epsilon 0.10089999999999999 - Mean Reward 1048.28 - Mean Length 180.21 - Mean Loss 1.046 - Mean Q Value 56.867 - Time Delta 5.237 - Time 2025-05-12T05:02:39
# Episode 9991 - Step 1954646 - Epsilon 0.10080999999999996 - Mean Reward 1055.16 - Mean Length 181.26 - Mean Loss 1.042 - Mean Q Value 56.864 - Time Delta 4.947 - Time 2025-05-12T05:02:44
# Episode 9992 - Step 1954846 - Epsilon 0.10072000000000003 - Mean Reward 1057.84 - Mean Length 181.61 - Mean Loss 1.039 - Mean Q Value 56.869 - Time Delta 4.903 - Time 2025-05-12T05:02:49
# Episode 9993 - Step 1955051 - Epsilon 0.10063 - Mean Reward 1064.61 - Mean Length 182.1 - Mean Loss 1.035 - Mean Q Value 56.868 - Time Delta 4.97 - Time 2025-05-12T05:02:54
# Episode 9994 - Step 1955284 - Epsilon 0.10054000000000007 - Mean Reward 1068.23 - Mean Length 182.83 - Mean Loss 1.027 - Mean Q Value 56.883 - Time Delta 5.592 - Time 2025-05-12T05:02:59
# Episode 9995 - Step 1955480 - Epsilon 0.10044999999999993 - Mean Reward 1072.29 - Mean Length 183.22 - Mean Loss 1.023 - Mean Q Value 56.898 - Time Delta 4.781 - Time 2025-05-12T05:03:04
# Episode 9996 - Step 1955652 - Epsilon 0.1003599999999999 - Mean Reward 1072.28 - Mean Length 183.33 - Mean Loss 1.016 - Mean Q Value 56.905 - Time Delta 4.228 - Time 2025-05-12T05:03:08
# Episode 9997 - Step 1955692 - Epsilon 0.10026999999999997 - Mean Reward 1061.46 - Mean Length 181.65 - Mean Loss 1.013 - Mean Q Value 56.901 - Time Delta 1.265 - Time 2025-05-12T05:03:09
# Episode 9998 - Step 1955913 - Epsilon 0.10017999999999994 - Mean Reward 1068.3 - Mean Length 182.88 - Mean Loss 1.007 - Mean Q Value 56.905 - Time Delta 5.307 - Time 2025-05-12T05:03:15
# Episode 9999 - Step 1956134 - Epsilon 0.10009000000000001 - Mean Reward 1075.04 - Mean Length 183.52 - Mean Loss 1.003 - Mean Q Value 56.91 - Time Delta 5.303 - Time 2025-05-12T05:03:20

# %% [markdown]
# Conclusion
# ==========
#
# In this tutorial, we saw how we can use PyTorch to train a game-playing
# AI. You can use the same methods to train an AI to play any of the games
# at the [OpenAI gym](https://gym.openai.com/). Hope you enjoyed this
# tutorial, feel free to reach us at [our
# github](https://github.com/yuansongFeng/MadMario/)!
